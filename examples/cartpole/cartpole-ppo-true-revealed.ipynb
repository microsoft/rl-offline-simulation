# %%
import gym
import numpy as np
from offsim4rl.envs import gridworld
from offsim4rl.agents import spinup
import torch
# Out:
# /anaconda/envs/offsim4rl2/lib/python3.7/site-packages/matplotlib/__init__.py:200: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(module.__version__) < minver:
# /anaconda/envs/offsim4rl2/lib/python3.7/site-packages/setuptools/_distutils/version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /anaconda/envs/offsim4rl2/lib/python3.7/site-packages/tensorflow_core/python/pywrap_tensorflow_internal.py:15: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# /anaconda/envs/offsim4rl2/lib/python3.7/site-packages/keras_preprocessing/image/utils.py:23: DeprecationWarning: NEAREST is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.NEAREST or Dither.NONE instead.
#   'nearest': pil_image.NEAREST,
# /anaconda/envs/offsim4rl2/lib/python3.7/site-packages/keras_preprocessing/image/utils.py:24: DeprecationWarning: BILINEAR is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BILINEAR instead.
#   'bilinear': pil_image.BILINEAR,
# /anaconda/envs/offsim4rl2/lib/python3.7/site-packages/keras_preprocessing/image/utils.py:25: DeprecationWarning: BICUBIC is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BICUBIC instead.
#   'bicubic': pil_image.BICUBIC,
# /anaconda/envs/offsim4rl2/lib/python3.7/site-packages/keras_preprocessing/image/utils.py:28: DeprecationWarning: HAMMING is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.HAMMING instead.
#   if hasattr(pil_image, 'HAMMING'):
# /anaconda/envs/offsim4rl2/lib/python3.7/site-packages/keras_preprocessing/image/utils.py:30: DeprecationWarning: BOX is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BOX instead.
#   if hasattr(pil_image, 'BOX'):
# /anaconda/envs/offsim4rl2/lib/python3.7/site-packages/keras_preprocessing/image/utils.py:33: DeprecationWarning: LANCZOS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   if hasattr(pil_image, 'LANCZOS'):
# No protocol specified

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# true env for online learning and online validation
env = gym.make('CartPole-v1')
env.seed(100000)
# Out:
# /anaconda/envs/offsim4rl2/lib/python3.7/site-packages/gym/core.py:318: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   "Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future."
# /anaconda/envs/offsim4rl2/lib/python3.7/site-packages/gym/wrappers/step_api_compatibility.py:40: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   "Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future."
# /anaconda/envs/offsim4rl2/lib/python3.7/site-packages/gym/core.py:257: DeprecationWarning: WARN: Function `env.seed(seed)` is marked as deprecated and will be removed in the future. Please use `env.reset(seed=seed)` instead.
#   "Function `env.seed(seed)` is marked as deprecated and will be removed in the future. "
# [100000]

# %%
from offsim4rl.core import RevealedRandomnessEnvWrapper

# %%
for seed in range(10):
    spinup.ppo(
        env_fn=lambda: RevealedRandomnessEnvWrapper(env), steps_per_epoch=1000, epochs=100, seed=seed+100, 
        logger_kwargs=dict(output_dir=f'./outputs/cartpole_true_revealed/seed={seed}', exp_name='CartPole-v1_ppo'), 
        ac_kwargs=dict(hidden_sizes=[32, 32], activation=torch.nn.ReLU), 
        validate=True, val_kwargs=dict(val_env_fn=lambda: env, val_n_episodes=10))
# Out:
# Warning: Log dir ./outputs/cartpole_true_revealed/seed=0 already exists! Storing info there anyway.
# Logging data to ./outputs/cartpole_true_revealed/seed=0/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             32,
#             32
#         ]
#     },
#     "actor_critic":	"MLPActorCritic",
#     "clip_ratio":	0.2,
#     "env_fn":	"<function <lambda> at 0x7f15d6031170>",
#     "epochs":	100,
#     "exp_name":	"CartPole-v1_ppo",
#     "gamma":	0.99,
#     "lam":	0.97,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7f15d605fdd0>":	{
#             "epoch_dict":	{},
#             "exp_name":	"CartPole-v1_ppo",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"./outputs/cartpole_true_revealed/seed=0",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='./outputs/cartpole_true_revealed/seed=0/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"CartPole-v1_ppo",
#         "output_dir":	"./outputs/cartpole_true_revealed/seed=0"
#     },
#     "max_ep_len":	1000,
#     "pi_lr":	0.0003,
#     "save_freq":	10,
#     "seed":	100,
#     "steps_per_epoch":	1000,
#     "target_kl":	0.01,
#     "train_pi_iters":	80,
#     "train_v_iters":	80,
#     "val_kwargs":	{
#         "val_env_fn":	"<function <lambda> at 0x7f15d6031200>",
#         "val_n_episodes":	10
#     },
#     "validate":	true,
#     "vf_lr":	0.001
# }
#
# Number of parameters: 	 pi: 1282, 	 v: 1249
#
# Warning: trajectory cut off by epoch at 18 steps.
# ---------------------------------------
# |             Epoch |               0 |
# |      AverageEpRet |            23.4 |
# |          StdEpRet |            14.4 |
# |          MaxEpRet |              64 |
# |          MinEpRet |              10 |
# |             EpLen |            23.4 |
# |      AverageVVals |         -0.0229 |
# |          StdVVals |          0.0184 |
# |          MaxVVals |           0.102 |
# |          MinVVals |         -0.0669 |
# | TotalEnvInteracts |           1e+03 |
# |            LossPi |        1.03e-07 |
# |             LossV |             331 |
# |       DeltaLossPi |         -0.0148 |
# |        DeltaLossV |           -59.2 |
# |           Entropy |           0.693 |
# |                KL |         0.00512 |
# |          ClipFrac |           0.049 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            19.2 |
# |      StdVal_EpRet |            7.54 |
# |      MaxVal_EpRet |            35.7 |
# |      MinVal_EpRet |            11.4 |
# |  AverageVal_EpLen |            21.7 |
# |      StdVal_EpLen |            9.79 |
# |      MaxVal_EpLen |              44 |
# |      MinVal_EpLen |              12 |
# |              Time |           0.902 |
# ---------------------------------------
# /anaconda/envs/offsim4rl2/lib/python3.7/site-packages/gym/envs/classic_control/cartpole.py:180: UserWarning: WARN: You are calling 'step()' even though this environment has already returned terminated = True. You should always call 'reset()' once you receive 'terminated = True' -- any further steps are undefined behavior.
#   "You are calling 'step()' even though this "
# Warning: trajectory cut off by epoch at 24 steps.
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            23.8 |
# |          StdEpRet |            11.2 |
# |          MaxEpRet |              51 |
# |          MinEpRet |               0 |
# |             EpLen |            23.8 |
# |      AverageVVals |            2.34 |
# |          StdVVals |           0.444 |
# |          MaxVVals |            4.76 |
# |          MinVVals |             1.9 |
# | TotalEnvInteracts |           2e+03 |
# |            LossPi |       -9.63e-08 |
# |             LossV |             206 |
# |       DeltaLossPi |         -0.0162 |
# |        DeltaLossV |            -100 |
# |           Entropy |           0.687 |
# |                KL |           0.011 |
# |          ClipFrac |           0.035 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            29.2 |
# |      StdVal_EpRet |              10 |
# |      MaxVal_EpRet |            43.6 |
# |      MinVal_EpRet |            11.4 |
# |  AverageVal_EpLen |            35.3 |
# |      StdVal_EpLen |            14.1 |
# |      MaxVal_EpLen |              57 |
# |      MinVal_EpLen |              12 |
# |              Time |            1.73 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 3 steps.
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            31.1 |
# |          StdEpRet |              20 |
# |          MaxEpRet |              84 |
# |          MinEpRet |               0 |
# |             EpLen |            31.2 |
# |      AverageVVals |            9.72 |
# |          StdVVals |            1.44 |
# |          MaxVVals |              16 |
# |          MinVVals |             7.8 |
# | TotalEnvInteracts |           3e+03 |
# |            LossPi |       -4.58e-08 |
# |             LossV |             281 |
# |       DeltaLossPi |         -0.0199 |
# |        DeltaLossV |            -101 |
# |           Entropy |           0.672 |
# |                KL |           0.011 |
# |          ClipFrac |           0.041 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            33.5 |
# |      StdVal_EpRet |            9.18 |
# |      MaxVal_EpRet |              50 |
# |      MinVal_EpRet |            18.2 |
# |  AverageVal_EpLen |            41.6 |
# |      StdVal_EpLen |            13.8 |
# |      MaxVal_EpLen |              69 |
# |      MinVal_EpLen |              20 |
# |              Time |            2.59 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 13 steps.
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            49.3 |
# |          StdEpRet |            37.5 |
# |          MaxEpRet |             144 |
# |          MinEpRet |               0 |
# |             EpLen |            49.3 |
# |      AverageVVals |            18.5 |
# |          StdVVals |            1.18 |
# |          MaxVVals |            25.8 |
# |          MinVVals |            16.1 |
# | TotalEnvInteracts |           4e+03 |
# |            LossPi |        4.24e-08 |
# |             LossV |             527 |
# |       DeltaLossPi |         -0.0189 |
# |        DeltaLossV |            -143 |
# |           Entropy |           0.656 |
# |                KL |         0.00729 |
# |          ClipFrac |           0.074 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            50.8 |
# |      StdVal_EpRet |            19.3 |
# |      MaxVal_EpRet |            84.1 |
# |      MinVal_EpRet |            16.5 |
# |  AverageVal_EpLen |              80 |
# |      StdVal_EpLen |            46.1 |
# |      MaxVal_EpLen |             183 |
# |      MinVal_EpLen |              18 |
# |              Time |            3.62 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 9 steps.
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            76.2 |
# |          StdEpRet |            47.8 |
# |          MaxEpRet |             156 |
# |          MinEpRet |               0 |
# |             EpLen |            76.2 |
# |      AverageVVals |              29 |
# |          StdVVals |            2.96 |
# |          MaxVVals |            39.9 |
# |          MinVVals |            20.7 |
# | TotalEnvInteracts |           5e+03 |
# |            LossPi |        3.11e-08 |
# |             LossV |             552 |
# |       DeltaLossPi |         -0.0149 |
# |        DeltaLossV |            -190 |
# |           Entropy |           0.643 |
# |                KL |        0.000869 |
# |          ClipFrac |           0.066 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            47.8 |
# |      StdVal_EpRet |            22.9 |
# |      MaxVal_EpRet |            83.9 |
# |      MinVal_EpRet |            22.2 |
# |  AverageVal_EpLen |            77.1 |
# |      StdVal_EpLen |            53.1 |
# |      MaxVal_EpLen |             182 |
# |      MinVal_EpLen |              25 |
# |              Time |            4.62 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 123 steps.
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            97.3 |
# |          StdEpRet |            62.9 |
# |          MaxEpRet |             184 |
# |          MinEpRet |               0 |
# |             EpLen |            97.4 |
# |      AverageVVals |            39.6 |
# |          StdVVals |             5.2 |
# |          MaxVVals |            44.9 |
# |          MinVVals |            19.8 |
# | TotalEnvInteracts |           6e+03 |
# |            LossPi |        1.53e-08 |
# |             LossV |             570 |
# |       DeltaLossPi |         -0.0204 |
# |        DeltaLossV |            -103 |
# |           Entropy |           0.634 |
# |                KL |          0.0033 |
# |          ClipFrac |           0.048 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            69.9 |
# |      StdVal_EpRet |            12.4 |
# |      MaxVal_EpRet |            82.1 |
# |      MinVal_EpRet |            44.2 |
# |  AverageVal_EpLen |             127 |
# |      StdVal_EpLen |            36.9 |
# |      MaxVal_EpLen |             171 |
# |      MinVal_EpLen |              58 |
# |              Time |            5.83 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 65 steps.
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |             104 |
# |          StdEpRet |            71.2 |
# |          MaxEpRet |             227 |
# |          MinEpRet |               0 |
# |             EpLen |             104 |
# |      AverageVVals |            44.4 |
# |          StdVVals |             9.6 |
# |          MaxVVals |            53.2 |
# |          MinVVals |            4.27 |
# | TotalEnvInteracts |           7e+03 |
# |            LossPi |       -4.05e-08 |
# |             LossV |             400 |
# |       DeltaLossPi |         -0.0164 |
# |        DeltaLossV |             -89 |
# |           Entropy |           0.608 |
# |                KL |         0.00984 |
# |          ClipFrac |           0.114 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            72.6 |
# |      StdVal_EpRet |            14.8 |
# |      MaxVal_EpRet |            98.1 |
# |      MinVal_EpRet |            49.5 |
# |  AverageVal_EpLen |             155 |
# |      StdVal_EpLen |            89.7 |
# |      MaxVal_EpLen |             393 |
# |      MinVal_EpLen |              68 |
# |              Time |            7.24 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 71 steps.
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |             155 |
# |          StdEpRet |            79.8 |
# |          MaxEpRet |             243 |
# |          MinEpRet |               0 |
# |             EpLen |             155 |
# |      AverageVVals |            53.7 |
# |          StdVVals |            9.81 |
# |          MaxVVals |            63.8 |
# |          MinVVals |            21.9 |
# | TotalEnvInteracts |           8e+03 |
# |            LossPi |        6.44e-09 |
# |             LossV |             382 |
# |       DeltaLossPi |         -0.0163 |
# |        DeltaLossV |             -92 |
# |           Entropy |           0.592 |
# |                KL |         0.00726 |
# |          ClipFrac |           0.039 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            86.5 |
# |      StdVal_EpRet |            9.08 |
# |      MaxVal_EpRet |            98.6 |
# |      MinVal_EpRet |            70.7 |
# |  AverageVal_EpLen |             235 |
# |      StdVal_EpLen |            95.1 |
# |      MaxVal_EpLen |             425 |
# |      MinVal_EpLen |             122 |
# |              Time |            8.92 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 41 steps.
# Early stopping at step 10 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |             137 |
# |          StdEpRet |             102 |
# |          MaxEpRet |             357 |
# |          MinEpRet |               0 |
# |             EpLen |             137 |
# |      AverageVVals |            53.3 |
# |          StdVVals |            22.8 |
# |          MaxVVals |            76.7 |
# |          MinVVals |           -30.4 |
# | TotalEnvInteracts |           9e+03 |
# |            LossPi |         1.5e-08 |
# |             LossV |             433 |
# |       DeltaLossPi |         -0.0093 |
# |        DeltaLossV |            -175 |
# |           Entropy |           0.578 |
# |                KL |          0.0171 |
# |          ClipFrac |           0.128 |
# |          StopIter |              10 |
# |  AverageVal_EpRet |            84.3 |
# |      StdVal_EpRet |            8.17 |
# |      MaxVal_EpRet |            94.2 |
# |      MinVal_EpRet |            67.2 |
# |  AverageVal_EpLen |             198 |
# |      StdVal_EpLen |            54.3 |
# |      MaxVal_EpLen |             283 |
# |      MinVal_EpLen |             111 |
# |              Time |            10.3 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 34 steps.
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |             193 |
# |          StdEpRet |             151 |
# |          MaxEpRet |             434 |
# |          MinEpRet |               0 |
# |             EpLen |             193 |
# |      AverageVVals |            55.9 |
# |          StdVVals |            23.7 |
# |          MaxVVals |              78 |
# |          MinVVals |             -72 |
# | TotalEnvInteracts |           1e+04 |
# |            LossPi |        -6.2e-09 |
# |             LossV |             613 |
# |       DeltaLossPi |         -0.0133 |
# |        DeltaLossV |            -312 |
# |           Entropy |           0.579 |
# |                KL |          0.0108 |
# |          ClipFrac |           0.119 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            83.9 |
# |      StdVal_EpRet |            9.72 |
# |      MaxVal_EpRet |            98.6 |
# |      MinVal_EpRet |            66.2 |
# |  AverageVal_EpLen |             211 |
# |      StdVal_EpLen |            90.3 |
# |      MaxVal_EpLen |             424 |
# |      MinVal_EpLen |             108 |
# |              Time |            11.9 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 78 steps.
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |             154 |
# |          StdEpRet |            79.3 |
# |          MaxEpRet |             262 |
# |          MinEpRet |               0 |
# |             EpLen |             154 |
# |      AverageVVals |            52.9 |
# |          StdVVals |            28.1 |
# |          MaxVVals |            85.1 |
# |          MinVVals |           -13.5 |
# | TotalEnvInteracts |         1.1e+04 |
# |            LossPi |        5.96e-10 |
# |             LossV |             311 |
# |       DeltaLossPi |         -0.0107 |
# |        DeltaLossV |            -158 |
# |           Entropy |           0.571 |
# |                KL |         0.00295 |
# |          ClipFrac |           0.047 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            92.6 |
# |      StdVal_EpRet |            4.31 |
# |      MaxVal_EpRet |            98.5 |
# |      MinVal_EpRet |            86.5 |
# |  AverageVal_EpLen |             283 |
# |      StdVal_EpLen |            77.4 |
# |      MaxVal_EpLen |             419 |
# |      MinVal_EpLen |             199 |
# |              Time |            13.8 |
# ---------------------------------------
# /anaconda/envs/offsim4rl2/lib/python3.7/site-packages/gym/envs/classic_control/cartpole.py:180: UserWarning: WARN: You are calling 'step()' even though this environment has already returned terminated = True. You should always call 'reset()' once you receive 'terminated = True' -- any further steps are undefined behavior.
#   "You are calling 'step()' even though this "
# Warning: trajectory cut off by epoch at 85 steps.
# Early stopping at step 32 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |             183 |
# |          StdEpRet |              96 |
# |          MaxEpRet |             268 |
# |          MinEpRet |               0 |
# |             EpLen |             183 |
# |      AverageVVals |            55.2 |
# |          StdVVals |            17.9 |
# |          MaxVVals |            81.8 |
# |          MinVVals |            11.2 |
# | TotalEnvInteracts |         1.2e+04 |
# |            LossPi |       -1.48e-08 |
# |             LossV |             302 |
# |       DeltaLossPi |         -0.0129 |
# |        DeltaLossV |            -122 |
# |           Entropy |           0.571 |
# |                KL |          0.0152 |
# |          ClipFrac |           0.144 |
# |          StopIter |              32 |
# |  AverageVal_EpRet |            97.1 |
# |      StdVal_EpRet |            2.28 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |            92.6 |
# |  AverageVal_EpLen |             391 |
# |      StdVal_EpLen |            90.6 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             259 |
# |              Time |            16.1 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 158 steps.
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |             210 |
# |          StdEpRet |             124 |
# |          MaxEpRet |             304 |
# |          MinEpRet |               1 |
# |             EpLen |             210 |
# |      AverageVVals |            70.1 |
# |          StdVVals |            15.8 |
# |          MaxVVals |              89 |
# |          MinVVals |            25.4 |
# | TotalEnvInteracts |         1.3e+04 |
# |            LossPi |       -2.38e-09 |
# |             LossV |             126 |
# |       DeltaLossPi |         -0.0126 |
# |        DeltaLossV |           -73.3 |
# |           Entropy |           0.556 |
# |                KL |         0.00667 |
# |          ClipFrac |           0.095 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |              95 |
# |      StdVal_EpRet |            4.81 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |            83.6 |
# |  AverageVal_EpLen |             356 |
# |      StdVal_EpLen |             115 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             180 |
# |              Time |            18.3 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 17 steps.
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |             246 |
# |          StdEpRet |             162 |
# |          MaxEpRet |             440 |
# |          MinEpRet |               1 |
# |             EpLen |             246 |
# |      AverageVVals |            69.4 |
# |          StdVVals |            25.7 |
# |          MaxVVals |            97.2 |
# |          MinVVals |           -11.3 |
# | TotalEnvInteracts |         1.4e+04 |
# |            LossPi |       -1.24e-08 |
# |             LossV |             169 |
# |       DeltaLossPi |         -0.0103 |
# |        DeltaLossV |           -24.3 |
# |           Entropy |            0.55 |
# |                KL |         0.00057 |
# |          ClipFrac |           0.031 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            96.1 |
# |      StdVal_EpRet |             3.8 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |            86.6 |
# |  AverageVal_EpLen |             369 |
# |      StdVal_EpLen |             100 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             200 |
# |              Time |            20.6 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 47 steps.
# Early stopping at step 27 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |             318 |
# |          StdEpRet |             225 |
# |          MaxEpRet |             500 |
# |          MinEpRet |               1 |
# |             EpLen |             318 |
# |      AverageVVals |            77.4 |
# |          StdVVals |              21 |
# |          MaxVVals |            96.4 |
# |          MinVVals |           -1.47 |
# | TotalEnvInteracts |         1.5e+04 |
# |            LossPi |        1.55e-08 |
# |             LossV |            99.7 |
# |       DeltaLossPi |         -0.0101 |
# |        DeltaLossV |           -15.9 |
# |           Entropy |           0.521 |
# |                KL |           0.015 |
# |          ClipFrac |           0.223 |
# |          StopIter |              27 |
# |  AverageVal_EpRet |            89.8 |
# |      StdVal_EpRet |            4.24 |
# |      MaxVal_EpRet |              96 |
# |      MinVal_EpRet |            83.3 |
# |  AverageVal_EpLen |             237 |
# |      StdVal_EpLen |              46 |
# |      MaxVal_EpLen |             321 |
# |      MinVal_EpLen |             178 |
# |              Time |            22.2 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 15 steps.
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |             246 |
# |          StdEpRet |             177 |
# |          MaxEpRet |             500 |
# |          MinEpRet |               0 |
# |             EpLen |             246 |
# |      AverageVVals |            74.4 |
# |          StdVVals |            21.7 |
# |          MaxVVals |             101 |
# |          MinVVals |            10.7 |
# | TotalEnvInteracts |         1.6e+04 |
# |            LossPi |       -4.77e-09 |
# |             LossV |             439 |
# |       DeltaLossPi |         -0.0105 |
# |        DeltaLossV |            -338 |
# |           Entropy |            0.53 |
# |                KL |        0.000878 |
# |          ClipFrac |            0.06 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            95.9 |
# |      StdVal_EpRet |            2.99 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |              91 |
# |  AverageVal_EpLen |             354 |
# |      StdVal_EpLen |              95 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             240 |
# |              Time |            24.4 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 367 steps.
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |             211 |
# |          StdEpRet |             149 |
# |          MaxEpRet |             316 |
# |          MinEpRet |               0 |
# |             EpLen |             211 |
# |      AverageVVals |              63 |
# |          StdVVals |            34.9 |
# |          MaxVVals |            95.1 |
# |          MinVVals |           -65.2 |
# | TotalEnvInteracts |         1.7e+04 |
# |            LossPi |         2.5e-08 |
# |             LossV |             435 |
# |       DeltaLossPi |          -0.011 |
# |        DeltaLossV |            -393 |
# |           Entropy |            0.55 |
# |                KL |         0.00411 |
# |          ClipFrac |           0.081 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |              98 |
# |      StdVal_EpRet |            1.87 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |            93.6 |
# |  AverageVal_EpLen |             427 |
# |      StdVal_EpLen |            83.6 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             274 |
# |              Time |            26.9 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 262 steps.
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |             246 |
# |          StdEpRet |             204 |
# |          MaxEpRet |             500 |
# |          MinEpRet |               1 |
# |             EpLen |             246 |
# |      AverageVVals |            91.8 |
# |          StdVVals |            10.9 |
# |          MaxVVals |             101 |
# |          MinVVals |            54.4 |
# | TotalEnvInteracts |         1.8e+04 |
# |            LossPi |       -4.17e-10 |
# |             LossV |             461 |
# |       DeltaLossPi |        -0.00675 |
# |        DeltaLossV |            -214 |
# |           Entropy |           0.527 |
# |                KL |         0.00836 |
# |          ClipFrac |           0.095 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            95.9 |
# |      StdVal_EpRet |            2.16 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |            92.6 |
# |  AverageVal_EpLen |             337 |
# |      StdVal_EpLen |              71 |
# |      MaxVal_EpLen |             493 |
# |      MinVal_EpLen |             259 |
# |              Time |            29.1 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 395 steps.
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |             201 |
# |          StdEpRet |             142 |
# |          MaxEpRet |             309 |
# |          MinEpRet |               0 |
# |             EpLen |             202 |
# |      AverageVVals |            61.1 |
# |          StdVVals |              38 |
# |          MaxVVals |            94.7 |
# |          MinVVals |           -65.1 |
# | TotalEnvInteracts |         1.9e+04 |
# |            LossPi |       -1.57e-08 |
# |             LossV |             594 |
# |       DeltaLossPi |         -0.0115 |
# |        DeltaLossV |            -565 |
# |           Entropy |           0.558 |
# |                KL |         0.00331 |
# |          ClipFrac |            0.06 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            98.8 |
# |      StdVal_EpRet |           0.957 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |            96.9 |
# |  AverageVal_EpLen |             466 |
# |      StdVal_EpLen |            60.4 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             345 |
# |              Time |            31.8 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 499 steps.
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |             250 |
# |          StdEpRet |             250 |
# |          MaxEpRet |             500 |
# |          MinEpRet |               0 |
# |             EpLen |             250 |
# |      AverageVVals |            91.4 |
# |          StdVVals |            10.3 |
# |          MaxVVals |             105 |
# |          MinVVals |            60.1 |
# | TotalEnvInteracts |           2e+04 |
# |            LossPi |        2.29e-08 |
# |             LossV |             570 |
# |       DeltaLossPi |        -0.00395 |
# |        DeltaLossV |            -192 |
# |           Entropy |           0.535 |
# |                KL |         0.00499 |
# |          ClipFrac |           0.068 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            94.2 |
# |      StdVal_EpRet |            15.4 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |              48 |
# |  AverageVal_EpLen |             456 |
# |      StdVal_EpLen |             130 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |              65 |
# |              Time |            34.4 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 499 steps.
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |             250 |
# |          StdEpRet |             250 |
# |          MaxEpRet |             500 |
# |          MinEpRet |               1 |
# |             EpLen |             250 |
# |      AverageVVals |            79.6 |
# |          StdVVals |            10.4 |
# |          MaxVVals |            91.5 |
# |          MinVVals |            53.4 |
# | TotalEnvInteracts |         2.1e+04 |
# |            LossPi |       -7.15e-10 |
# |             LossV |             223 |
# |       DeltaLossPi |        -0.00446 |
# |        DeltaLossV |           -86.6 |
# |           Entropy |           0.529 |
# |                KL |         0.00738 |
# |          ClipFrac |           0.045 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            97.2 |
# |      StdVal_EpRet |            2.43 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |            92.2 |
# |  AverageVal_EpLen |             397 |
# |      StdVal_EpLen |            92.4 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             254 |
# |              Time |            36.8 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 313 steps.
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |             229 |
# |          StdEpRet |             163 |
# |          MaxEpRet |             374 |
# |          MinEpRet |               1 |
# |             EpLen |             229 |
# |      AverageVVals |            94.6 |
# |          StdVVals |            7.77 |
# |          MaxVVals |             104 |
# |          MinVVals |            58.3 |
# | TotalEnvInteracts |         2.2e+04 |
# |            LossPi |        1.14e-08 |
# |             LossV |             584 |
# |       DeltaLossPi |         -0.0107 |
# |        DeltaLossV |            -530 |
# |           Entropy |           0.553 |
# |                KL |         0.00371 |
# |          ClipFrac |           0.025 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |              98 |
# |      StdVal_EpRet |            2.03 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |            93.2 |
# |  AverageVal_EpLen |             433 |
# |      StdVal_EpLen |            84.5 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             268 |
# |              Time |            39.4 |
# ---------------------------------------
# /anaconda/envs/offsim4rl2/lib/python3.7/site-packages/gym/envs/classic_control/cartpole.py:180: UserWarning: WARN: You are calling 'step()' even though this environment has already returned terminated = True. You should always call 'reset()' once you receive 'terminated = True' -- any further steps are undefined behavior.
#   "You are calling 'step()' even though this "
# Warning: trajectory cut off by epoch at 127 steps.
# Early stopping at step 9 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |             291 |
# |          StdEpRet |             212 |
# |          MaxEpRet |             500 |
# |          MinEpRet |               0 |
# |             EpLen |             291 |
# |      AverageVVals |            87.7 |
# |          StdVVals |            18.5 |
# |          MaxVVals |             104 |
# |          MinVVals |           -7.36 |
# | TotalEnvInteracts |         2.3e+04 |
# |            LossPi |        3.19e-08 |
# |             LossV |             289 |
# |       DeltaLossPi |        -0.00891 |
# |        DeltaLossV |           -75.1 |
# |           Entropy |           0.543 |
# |                KL |          0.0169 |
# |          ClipFrac |           0.222 |
# |          StopIter |               9 |
# |  AverageVal_EpRet |            99.3 |
# |      StdVal_EpRet |           0.174 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |            98.8 |
# |  AverageVal_EpLen |             494 |
# |      StdVal_EpLen |            18.9 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             437 |
# |              Time |              42 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 499 steps.
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |             250 |
# |          StdEpRet |             250 |
# |          MaxEpRet |             500 |
# |          MinEpRet |               1 |
# |             EpLen |             250 |
# |      AverageVVals |            85.4 |
# |          StdVVals |            8.75 |
# |          MaxVVals |            97.7 |
# |          MinVVals |            71.9 |
# | TotalEnvInteracts |         2.4e+04 |
# |            LossPi |       -4.53e-09 |
# |             LossV |             288 |
# |       DeltaLossPi |        -0.00539 |
# |        DeltaLossV |             -18 |
# |           Entropy |           0.531 |
# |                KL |          0.0139 |
# |          ClipFrac |           0.132 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            98.3 |
# |      StdVal_EpRet |             2.7 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |            90.3 |
# |  AverageVal_EpLen |             459 |
# |      StdVal_EpLen |            83.7 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             232 |
# |              Time |            44.7 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 50 steps.
# Early stopping at step 10 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |             317 |
# |          StdEpRet |             224 |
# |          MaxEpRet |             500 |
# |          MinEpRet |               1 |
# |             EpLen |             317 |
# |      AverageVVals |            85.3 |
# |          StdVVals |            15.2 |
# |          MaxVVals |             101 |
# |          MinVVals |            32.3 |
# | TotalEnvInteracts |         2.5e+04 |
# |            LossPi |       -8.11e-09 |
# |             LossV |             394 |
# |       DeltaLossPi |        -0.00789 |
# |        DeltaLossV |           -48.8 |
# |           Entropy |           0.536 |
# |                KL |          0.0157 |
# |          ClipFrac |             0.2 |
# |          StopIter |              10 |
# |  AverageVal_EpRet |            99.3 |
# |      StdVal_EpRet |               0 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |            99.3 |
# |  AverageVal_EpLen |             500 |
# |      StdVal_EpLen |               0 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             500 |
# |              Time |            47.4 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 499 steps.
# Early stopping at step 10 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |             250 |
# |          StdEpRet |             250 |
# |          MaxEpRet |             500 |
# |          MinEpRet |               1 |
# |             EpLen |             250 |
# |      AverageVVals |            92.8 |
# |          StdVVals |            2.32 |
# |          MaxVVals |              96 |
# |          MinVVals |            84.1 |
# | TotalEnvInteracts |         2.6e+04 |
# |            LossPi |       -2.38e-10 |
# |             LossV |             364 |
# |       DeltaLossPi |        -0.00345 |
# |        DeltaLossV |            -120 |
# |           Entropy |           0.529 |
# |                KL |          0.0169 |
# |          ClipFrac |            0.23 |
# |          StopIter |              10 |
# |  AverageVal_EpRet |            99.1 |
# |      StdVal_EpRet |           0.407 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |            98.2 |
# |  AverageVal_EpLen |             477 |
# |      StdVal_EpLen |            36.3 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             399 |
# |              Time |              50 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 499 steps.
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |             250 |
# |          StdEpRet |             250 |
# |          MaxEpRet |             500 |
# |          MinEpRet |               1 |
# |             EpLen |             250 |
# |      AverageVVals |            40.9 |
# |          StdVVals |            38.2 |
# |          MaxVVals |            97.6 |
# |          MinVVals |           -24.8 |
# | TotalEnvInteracts |         2.7e+04 |
# |            LossPi |        7.75e-08 |
# |             LossV |        1.93e+03 |
# |       DeltaLossPi |        -0.00654 |
# |        DeltaLossV |       -1.77e+03 |
# |           Entropy |           0.534 |
# |                KL |         0.00401 |
# |          ClipFrac |            0.05 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            89.4 |
# |      StdVal_EpRet |            20.2 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |            37.6 |
# |  AverageVal_EpLen |             398 |
# |      StdVal_EpLen |             169 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |              47 |
# |              Time |            52.4 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 499 steps.
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |             250 |
# |          StdEpRet |             250 |
# |          MaxEpRet |             500 |
# |          MinEpRet |               1 |
# |             EpLen |             250 |
# |      AverageVVals |            89.1 |
# |          StdVVals |            15.2 |
# |          MaxVVals |             105 |
# |          MinVVals |            45.5 |
# | TotalEnvInteracts |         2.8e+04 |
# |            LossPi |       -1.67e-09 |
# |             LossV |             125 |
# |       DeltaLossPi |         -0.0113 |
# |        DeltaLossV |           -24.8 |
# |           Entropy |           0.527 |
# |                KL |         0.00421 |
# |          ClipFrac |           0.097 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |              99 |
# |      StdVal_EpRet |            0.65 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |            97.6 |
# |  AverageVal_EpLen |             475 |
# |      StdVal_EpLen |            49.5 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             371 |
# |              Time |            55.1 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 205 steps.
# Early stopping at step 26 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |             265 |
# |          StdEpRet |             195 |
# |          MaxEpRet |             468 |
# |          MinEpRet |               1 |
# |             EpLen |             265 |
# |      AverageVVals |              83 |
# |          StdVVals |            15.4 |
# |          MaxVVals |             103 |
# |          MinVVals |            46.3 |
# | TotalEnvInteracts |         2.9e+04 |
# |            LossPi |       -1.91e-09 |
# |             LossV |             276 |
# |       DeltaLossPi |        -0.00853 |
# |        DeltaLossV |           -30.9 |
# |           Entropy |           0.525 |
# |                KL |          0.0153 |
# |          ClipFrac |            0.15 |
# |          StopIter |              26 |
# |  AverageVal_EpRet |            99.3 |
# |      StdVal_EpRet |               0 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |            99.3 |
# |  AverageVal_EpLen |             500 |
# |      StdVal_EpLen |               0 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             500 |
# |              Time |            57.9 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 499 steps.
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |             250 |
# |          StdEpRet |             250 |
# |          MaxEpRet |             500 |
# |          MinEpRet |               1 |
# |             EpLen |             250 |
# |      AverageVVals |            86.2 |
# |          StdVVals |            10.2 |
# |          MaxVVals |             100 |
# |          MinVVals |            65.3 |
# | TotalEnvInteracts |           3e+04 |
# |            LossPi |       -1.26e-08 |
# |             LossV |             206 |
# |       DeltaLossPi |         -0.0064 |
# |        DeltaLossV |           -10.4 |
# |           Entropy |           0.523 |
# |                KL |          0.0139 |
# |          ClipFrac |           0.117 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            98.1 |
# |      StdVal_EpRet |             3.7 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |              87 |
# |  AverageVal_EpLen |             470 |
# |      StdVal_EpLen |            89.1 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             203 |
# |              Time |            60.6 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 499 steps.
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |             250 |
# |          StdEpRet |             250 |
# |          MaxEpRet |             500 |
# |          MinEpRet |               1 |
# |             EpLen |             250 |
# |      AverageVVals |              93 |
# |          StdVVals |            10.9 |
# |          MaxVVals |             105 |
# |          MinVVals |            64.9 |
# | TotalEnvInteracts |         3.1e+04 |
# |            LossPi |         6.2e-09 |
# |             LossV |             208 |
# |       DeltaLossPi |        -0.00835 |
# |        DeltaLossV |           -32.5 |
# |           Entropy |           0.555 |
# |                KL |        -0.00162 |
# |          ClipFrac |           0.021 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            99.1 |
# |      StdVal_EpRet |           0.709 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |              97 |
# |  AverageVal_EpLen |             480 |
# |      StdVal_EpLen |            46.5 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             348 |
# |              Time |            63.4 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 499 steps.
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |             250 |
# |          StdEpRet |             250 |
# |          MaxEpRet |             500 |
# |          MinEpRet |               1 |
# |             EpLen |             250 |
# |      AverageVVals |            92.9 |
# |          StdVVals |            10.5 |
# |          MaxVVals |             104 |
# |          MinVVals |            56.4 |
# | TotalEnvInteracts |         3.2e+04 |
# |            LossPi |       -1.19e-08 |
# |             LossV |             138 |
# |       DeltaLossPi |         -0.0149 |
# |        DeltaLossV |           -53.4 |
# |           Entropy |           0.546 |
# |                KL |          0.0133 |
# |          ClipFrac |           0.093 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            98.8 |
# |      StdVal_EpRet |           0.757 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |              97 |
# |  AverageVal_EpLen |             456 |
# |      StdVal_EpLen |            53.9 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             350 |
# |              Time |              66 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 36 steps.
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |             241 |
# |          StdEpRet |             180 |
# |          MaxEpRet |             500 |
# |          MinEpRet |               1 |
# |             EpLen |             241 |
# |      AverageVVals |            90.6 |
# |          StdVVals |            8.45 |
# |          MaxVVals |             105 |
# |          MinVVals |            70.4 |
# | TotalEnvInteracts |         3.3e+04 |
# |            LossPi |        2.24e-08 |
# |             LossV |             984 |
# |       DeltaLossPi |        -0.00929 |
# |        DeltaLossV |            -372 |
# |           Entropy |           0.557 |
# |                KL |         0.00687 |
# |          ClipFrac |           0.054 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            99.3 |
# |      StdVal_EpRet |               0 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |            99.3 |
# |  AverageVal_EpLen |             500 |
# |      StdVal_EpLen |               0 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             500 |
# |              Time |            68.9 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 73 steps.
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |             309 |
# |          StdEpRet |             220 |
# |          MaxEpRet |             500 |
# |          MinEpRet |               1 |
# |             EpLen |             309 |
# |      AverageVVals |            70.9 |
# |          StdVVals |            18.1 |
# |          MaxVVals |            87.6 |
# |          MinVVals |              15 |
# | TotalEnvInteracts |         3.4e+04 |
# |            LossPi |       -1.17e-08 |
# |             LossV |             486 |
# |       DeltaLossPi |        -0.00781 |
# |        DeltaLossV |            -108 |
# |           Entropy |           0.542 |
# |                KL |         0.00366 |
# |          ClipFrac |           0.126 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            99.2 |
# |      StdVal_EpRet |           0.568 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |            97.4 |
# |  AverageVal_EpLen |             486 |
# |      StdVal_EpLen |            40.5 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             365 |
# |              Time |            71.7 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 499 steps.
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |             250 |
# |          StdEpRet |             250 |
# |          MaxEpRet |             500 |
# |          MinEpRet |               1 |
# |             EpLen |             250 |
# |      AverageVVals |            86.4 |
# |          StdVVals |            3.24 |
# |          MaxVVals |            93.2 |
# |          MinVVals |              74 |
# | TotalEnvInteracts |         3.5e+04 |
# |            LossPi |        1.43e-09 |
# |             LossV |             405 |
# |       DeltaLossPi |        -0.00276 |
# |        DeltaLossV |           -12.9 |
# |           Entropy |           0.547 |
# |                KL |         0.00847 |
# |          ClipFrac |           0.088 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            99.3 |
# |      StdVal_EpRet |               0 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |            99.3 |
# |  AverageVal_EpLen |             500 |
# |      StdVal_EpLen |               0 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             500 |
# |              Time |            74.5 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 499 steps.
# Early stopping at step 28 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |             250 |
# |          StdEpRet |             250 |
# |          MaxEpRet |             500 |
# |          MinEpRet |               1 |
# |             EpLen |             250 |
# |      AverageVVals |            78.1 |
# |          StdVVals |            17.5 |
# |          MaxVVals |            94.7 |
# |          MinVVals |            28.4 |
# | TotalEnvInteracts |         3.6e+04 |
# |            LossPi |        1.98e-08 |
# |             LossV |             148 |
# |       DeltaLossPi |        -0.00936 |
# |        DeltaLossV |           -38.2 |
# |           Entropy |           0.527 |
# |                KL |           0.015 |
# |          ClipFrac |           0.187 |
# |          StopIter |              28 |
# |  AverageVal_EpRet |            94.3 |
# |      StdVal_EpRet |            14.1 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |              52 |
# |  AverageVal_EpLen |             434 |
# |      StdVal_EpLen |             129 |
# ...
# |          StdVVals |            2.64 |
# |          MaxVVals |              99 |
# |          MinVVals |            86.7 |
# | TotalEnvInteracts |         8.8e+04 |
# |            LossPi |       -2.38e-09 |
# |             LossV |             400 |
# |       DeltaLossPi |        -0.00451 |
# |        DeltaLossV |            -127 |
# |           Entropy |           0.487 |
# |                KL |         0.00551 |
# |          ClipFrac |           0.029 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            99.3 |
# |      StdVal_EpRet |               0 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |            99.3 |
# |  AverageVal_EpLen |             500 |
# |      StdVal_EpLen |               0 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             500 |
# |              Time |             219 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 499 steps.
# Early stopping at step 10 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              88 |
# |      AverageEpRet |             250 |
# |          StdEpRet |             250 |
# |          MaxEpRet |             500 |
# |          MinEpRet |               1 |
# |             EpLen |             250 |
# |      AverageVVals |            74.9 |
# |          StdVVals |            7.54 |
# |          MaxVVals |              89 |
# |          MinVVals |              56 |
# | TotalEnvInteracts |         8.9e+04 |
# |            LossPi |        9.54e-10 |
# |             LossV |             707 |
# |       DeltaLossPi |         -0.0047 |
# |        DeltaLossV |            -272 |
# |           Entropy |           0.472 |
# |                KL |          0.0171 |
# |          ClipFrac |           0.187 |
# |          StopIter |              10 |
# |  AverageVal_EpRet |            99.3 |
# |      StdVal_EpRet |               0 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |            99.3 |
# |  AverageVal_EpLen |             500 |
# |      StdVal_EpLen |               0 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             500 |
# |              Time |             222 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 499 steps.
# ---------------------------------------
# |             Epoch |              89 |
# |      AverageEpRet |             250 |
# |          StdEpRet |             250 |
# |          MaxEpRet |             500 |
# |          MinEpRet |               1 |
# |             EpLen |             250 |
# |      AverageVVals |            92.8 |
# |          StdVVals |            2.07 |
# |          MaxVVals |            98.4 |
# |          MinVVals |            84.2 |
# | TotalEnvInteracts |           9e+04 |
# |            LossPi |        1.57e-08 |
# |             LossV |             382 |
# |       DeltaLossPi |        -0.00685 |
# |        DeltaLossV |           -28.4 |
# |           Entropy |           0.498 |
# |                KL |         0.00468 |
# |          ClipFrac |           0.045 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            99.3 |
# |      StdVal_EpRet |               0 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |            99.3 |
# |  AverageVal_EpLen |             500 |
# |      StdVal_EpLen |               0 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             500 |
# |              Time |             225 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 499 steps.
# ---------------------------------------
# |             Epoch |              90 |
# |      AverageEpRet |             250 |
# |          StdEpRet |             250 |
# |          MaxEpRet |             500 |
# |          MinEpRet |               1 |
# |             EpLen |             250 |
# |      AverageVVals |            92.8 |
# |          StdVVals |            2.48 |
# |          MaxVVals |            98.5 |
# |          MinVVals |            87.7 |
# | TotalEnvInteracts |         9.1e+04 |
# |            LossPi |        3.34e-09 |
# |             LossV |             366 |
# |       DeltaLossPi |        -0.00387 |
# |        DeltaLossV |           -47.4 |
# |           Entropy |           0.499 |
# |                KL |         0.00597 |
# |          ClipFrac |           0.066 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            99.3 |
# |      StdVal_EpRet |               0 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |            99.3 |
# |  AverageVal_EpLen |             500 |
# |      StdVal_EpLen |               0 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             500 |
# |              Time |             228 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 499 steps.
# ---------------------------------------
# |             Epoch |              91 |
# |      AverageEpRet |             250 |
# |          StdEpRet |             250 |
# |          MaxEpRet |             500 |
# |          MinEpRet |               1 |
# |             EpLen |             250 |
# |      AverageVVals |            92.3 |
# |          StdVVals |            2.47 |
# |          MaxVVals |            97.5 |
# |          MinVVals |            86.2 |
# | TotalEnvInteracts |         9.2e+04 |
# |            LossPi |       -2.38e-09 |
# |             LossV |             384 |
# |       DeltaLossPi |        -0.00758 |
# |        DeltaLossV |           -21.9 |
# |           Entropy |           0.493 |
# |                KL |         0.00606 |
# |          ClipFrac |           0.106 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |              93 |
# |      StdVal_EpRet |            19.1 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |            35.7 |
# |  AverageVal_EpLen |             454 |
# |      StdVal_EpLen |             137 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |              44 |
# |              Time |             230 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 499 steps.
# ---------------------------------------
# |             Epoch |              92 |
# |      AverageEpRet |             250 |
# |          StdEpRet |             250 |
# |          MaxEpRet |             500 |
# |          MinEpRet |               1 |
# |             EpLen |             250 |
# |      AverageVVals |            91.6 |
# |          StdVVals |            2.69 |
# |          MaxVVals |            97.9 |
# |          MinVVals |            84.6 |
# | TotalEnvInteracts |         9.3e+04 |
# |            LossPi |        1.91e-09 |
# |             LossV |             388 |
# |       DeltaLossPi |        -0.00376 |
# |        DeltaLossV |           -48.4 |
# |           Entropy |           0.504 |
# |                KL |         0.00158 |
# |          ClipFrac |           0.021 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            99.3 |
# |      StdVal_EpRet |               0 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |            99.3 |
# |  AverageVal_EpLen |             500 |
# |      StdVal_EpLen |               0 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             500 |
# |              Time |             233 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 499 steps.
# Early stopping at step 12 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              93 |
# |      AverageEpRet |             250 |
# |          StdEpRet |             250 |
# |          MaxEpRet |             500 |
# |          MinEpRet |               1 |
# |             EpLen |             250 |
# |      AverageVVals |            86.3 |
# |          StdVVals |            5.16 |
# |          MaxVVals |            96.5 |
# |          MinVVals |              76 |
# | TotalEnvInteracts |         9.4e+04 |
# |            LossPi |       -9.54e-10 |
# |             LossV |             421 |
# |       DeltaLossPi |         -0.0041 |
# |        DeltaLossV |           -18.6 |
# |           Entropy |           0.491 |
# |                KL |          0.0153 |
# |          ClipFrac |           0.257 |
# |          StopIter |              12 |
# |  AverageVal_EpRet |            99.3 |
# |      StdVal_EpRet |               0 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |            99.3 |
# |  AverageVal_EpLen |             500 |
# |      StdVal_EpLen |               0 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             500 |
# |              Time |             236 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 499 steps.
# ---------------------------------------
# |             Epoch |              94 |
# |      AverageEpRet |             250 |
# |          StdEpRet |             250 |
# |          MaxEpRet |             500 |
# |          MinEpRet |               1 |
# |             EpLen |             250 |
# |      AverageVVals |            93.6 |
# |          StdVVals |             1.6 |
# |          MaxVVals |              98 |
# |          MinVVals |            87.5 |
# | TotalEnvInteracts |         9.5e+04 |
# |            LossPi |       -5.72e-09 |
# |             LossV |             408 |
# |       DeltaLossPi |        -0.00645 |
# |        DeltaLossV |           -18.7 |
# |           Entropy |           0.482 |
# |                KL |         0.00591 |
# |          ClipFrac |           0.105 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            99.3 |
# |      StdVal_EpRet |               0 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |            99.3 |
# |  AverageVal_EpLen |             500 |
# |      StdVal_EpLen |               0 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             500 |
# |              Time |             239 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 499 steps.
# ---------------------------------------
# |             Epoch |              95 |
# |      AverageEpRet |             250 |
# |          StdEpRet |             250 |
# |          MaxEpRet |             500 |
# |          MinEpRet |               1 |
# |             EpLen |             250 |
# |      AverageVVals |            89.7 |
# |          StdVVals |            1.83 |
# |          MaxVVals |            92.8 |
# |          MinVVals |            80.4 |
# | TotalEnvInteracts |         9.6e+04 |
# |            LossPi |       -2.86e-09 |
# |             LossV |             378 |
# |       DeltaLossPi |        -0.00828 |
# |        DeltaLossV |           -19.1 |
# |           Entropy |           0.476 |
# |                KL |         0.00161 |
# |          ClipFrac |            0.06 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            99.3 |
# |      StdVal_EpRet |               0 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |            99.3 |
# |  AverageVal_EpLen |             500 |
# |      StdVal_EpLen |               0 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             500 |
# |              Time |             241 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 499 steps.
# ---------------------------------------
# |             Epoch |              96 |
# |      AverageEpRet |             250 |
# |          StdEpRet |             250 |
# |          MaxEpRet |             500 |
# |          MinEpRet |               1 |
# |             EpLen |             250 |
# |      AverageVVals |            88.8 |
# |          StdVVals |            3.61 |
# |          MaxVVals |              96 |
# |          MinVVals |            78.1 |
# | TotalEnvInteracts |         9.7e+04 |
# |            LossPi |        1.05e-08 |
# |             LossV |             462 |
# |       DeltaLossPi |        -0.00832 |
# |        DeltaLossV |            -159 |
# |           Entropy |            0.47 |
# |                KL |          0.0104 |
# |          ClipFrac |            0.09 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            99.3 |
# |      StdVal_EpRet |               0 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |            99.3 |
# |  AverageVal_EpLen |             500 |
# |      StdVal_EpLen |               0 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             500 |
# |              Time |             244 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 499 steps.
# ---------------------------------------
# |             Epoch |              97 |
# |      AverageEpRet |             250 |
# |          StdEpRet |             250 |
# |          MaxEpRet |             500 |
# |          MinEpRet |               1 |
# |             EpLen |             250 |
# |      AverageVVals |            90.1 |
# |          StdVVals |            2.13 |
# |          MaxVVals |            95.1 |
# |          MinVVals |            83.7 |
# | TotalEnvInteracts |         9.8e+04 |
# |            LossPi |       -8.11e-09 |
# |             LossV |             396 |
# |       DeltaLossPi |        -0.00782 |
# |        DeltaLossV |           -22.2 |
# |           Entropy |           0.501 |
# |                KL |         0.00335 |
# |          ClipFrac |           0.086 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            99.3 |
# |      StdVal_EpRet |               0 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |            99.3 |
# |  AverageVal_EpLen |             500 |
# |      StdVal_EpLen |               0 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             500 |
# |              Time |             247 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 323 steps.
# ---------------------------------------
# |             Epoch |              98 |
# |      AverageEpRet |             226 |
# |          StdEpRet |             207 |
# |          MaxEpRet |             500 |
# |          MinEpRet |               1 |
# |             EpLen |             226 |
# |      AverageVVals |            88.9 |
# |          StdVVals |            2.67 |
# |          MaxVVals |            93.9 |
# |          MinVVals |            67.9 |
# | TotalEnvInteracts |         9.9e+04 |
# |            LossPi |        8.34e-09 |
# |             LossV |             705 |
# |       DeltaLossPi |        -0.00922 |
# |        DeltaLossV |            -115 |
# |           Entropy |            0.52 |
# |                KL |         0.00271 |
# |          ClipFrac |           0.037 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            99.3 |
# |      StdVal_EpRet |               0 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |            99.3 |
# |  AverageVal_EpLen |             500 |
# |      StdVal_EpLen |               0 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             500 |
# |              Time |             250 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 499 steps.
# ---------------------------------------
# |             Epoch |              99 |
# |      AverageEpRet |             250 |
# |          StdEpRet |             250 |
# |          MaxEpRet |             500 |
# |          MinEpRet |               1 |
# |             EpLen |             250 |
# |      AverageVVals |            81.4 |
# |          StdVVals |            3.02 |
# |          MaxVVals |            86.1 |
# |          MinVVals |            63.4 |
# | TotalEnvInteracts |           1e+05 |
# |            LossPi |        8.11e-09 |
# |             LossV |             455 |
# |       DeltaLossPi |         -0.0106 |
# |        DeltaLossV |            -133 |
# |           Entropy |           0.509 |
# |                KL |         0.00429 |
# |          ClipFrac |            0.06 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |            99.3 |
# |      StdVal_EpRet |               0 |
# |      MaxVal_EpRet |            99.3 |
# |      MinVal_EpRet |            99.3 |
# |  AverageVal_EpLen |             500 |
# |      StdVal_EpLen |               0 |
# |      MaxVal_EpLen |             500 |
# |      MinVal_EpLen |             500 |
# |              Time |             253 |
# ---------------------------------------

# %% [markdown]
# ## Visualize learning curves

# %%
dfs = [pd.read_csv(f'./outputs/cartpole_true_revealed/seed={seed}/progress.txt', sep='\t') for seed in range(10)]

# %% [markdown]
# ### All runs

# %%
for df in dfs:
    plt.plot(df['AverageVal_EpLen'])
    plt.fill_between(df['Epoch'], df['MinVal_EpLen'], df['MaxVal_EpLen'], alpha=0.1)
plt.xlabel('epoch')
plt.ylabel('Val EpLen')
plt.show()

# %%
for df in dfs:
    plt.plot(df['AverageVal_EpRet'])
    plt.fill_between(df['Epoch'], df['MinVal_EpRet'], df['MaxVal_EpRet'], alpha=0.1)
plt.xlabel('epoch')
plt.ylabel('Val EpRet')
plt.show()

# %% [markdown]
# ### Averaged

# %%
df_ = pd.concat(dfs).groupby('Epoch').mean().reset_index()

# %%
plt.plot(df_['AverageVal_EpLen'], color='k')
plt.fill_between(df_['Epoch'], df_['MinVal_EpLen'], df_['MaxVal_EpLen'], alpha=0.2, color='k')
plt.xlabel('epoch')
plt.ylabel('Val EpLen')
plt.show()

# %%
plt.plot(df_['AverageVal_EpRet'], color='k')
plt.fill_between(df_['Epoch'], df_['MinVal_EpRet'], df_['MaxVal_EpRet'], alpha=0.2, color='k')
plt.xlabel('epoch')
plt.ylabel('Val EpRet')
plt.show()
