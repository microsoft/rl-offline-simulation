# %%
import gym
import numpy as np
from offsim4rl.envs import gridworld
from offsim4rl.agents import spinup
import torch
# Out:
# No protocol specified

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from offsim4rl.data import OfflineDataset, ProbDistribution
from offsim4rl.evaluators.queue_evaluator import QueueEvaluator

# %%
# the oracle observation-to-state mapping for the continuous gridworld
class OracleEncoder(object):
    def __init__(self):
        pass
    def encode(self, observations):
        zs = []
        for x, y in observations:
            xx, yy = int(x*5), int(y*5)
            z = xx + 5*yy
            zs.append(z)
        return zs

# %%
from offsim4rl.utils.dataset_utils import load_h5_dataset
buffer = load_h5_dataset('../outputs/MyGridNaviCoords-v1_random.h5')
# Out:
# load datafile: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 33.37it/s]

# %%
dataset = OfflineDataset(
    observation_space=gym.spaces.Box(low=0, high=1, shape=(2,)),
    action_space=gym.spaces.Discrete(5),
    action_dist_type=ProbDistribution.Discrete,
    observations=buffer['observations'],
    actions=buffer['actions'].astype(int),
    action_distributions=buffer['infos/probs'],
    rewards=buffer['rewards'],
    next_observations=buffer['next_observations'],
    terminals=buffer['terminals'].astype(bool),
    steps=buffer['infos/steps'].astype(int),
)
# Out:
# WARNING:root:Missing episode_ids in experience. Some algorithms may not be compatible with this dataset.

# %%
qbe = QueueEvaluator(
    dataset,
    num_states=25,
    encoder=OracleEncoder(),
)

# %% [markdown]
# ## Learn

# %%
# true env for online validation
env = gym.make('MyGridNaviCoords-v1', seed=100000)
env.reset_task(np.array([4, 4]))
# Out:
# array([4, 4])

# %%
for seed in range(10):
    qbe.reset_sampler(seed=seed)
    spinup.ppo_revealed(
        env_fn=lambda: qbe, steps_per_epoch=5000, epochs=50, seed=seed, 
        logger_kwargs=dict(output_dir=f'./outputs/grid_qbe_oracle_revealed/seed={seed}', exp_name='MyGridNaviCoords-v1_ppo'), 
        ac_kwargs=dict(hidden_sizes=[32, 32], activation=torch.nn.ReLU), 
        validate=True, val_kwargs=dict(val_env_fn=lambda: env, val_n_episodes=10))
# Out:
# Warning: Log dir ./outputs/grid_qbe_oracle_revealed/seed=0 already exists! Storing info there anyway.
# Logging data to ./outputs/grid_qbe_oracle_revealed/seed=0/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             32,
#             32
#         ]
#     },
#     "actor_critic":	"MLPActorCritic",
#     "clip_ratio":	0.2,
#     "env_fn":	"<function <lambda> at 0x7efb6ad7a290>",
#     "epochs":	50,
#     "exp_name":	"MyGridNaviCoords-v1_ppo",
#     "gamma":	0.99,
#     "lam":	0.97,
#     "logger":	{
#         "<offsim4rl.agents.spinup.utils.logx.EpochLogger object at 0x7efb6eebc0d0>":	{
#             "epoch_dict":	{},
#             "exp_name":	"MyGridNaviCoords-v1_ppo",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"./outputs/grid_qbe_oracle_revealed/seed=0",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='./outputs/grid_qbe_oracle_revealed/seed=0/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"MyGridNaviCoords-v1_ppo",
#         "output_dir":	"./outputs/grid_qbe_oracle_revealed/seed=0"
#     },
#     "max_ep_len":	1000,
#     "pi_lr":	0.0003,
#     "save_freq":	10,
#     "seed":	0,
#     "steps_per_epoch":	5000,
#     "target_kl":	0.01,
#     "train_pi_iters":	80,
#     "train_v_iters":	80,
#     "val_kwargs":	{
#         "val_env_fn":	"<function <lambda> at 0x7efb6ad7aa70>",
#         "val_n_episodes":	10
#     },
#     "validate":	true,
#     "vf_lr":	0.001
# }
#
# Number of parameters: 	 pi: 1317, 	 v: 1185
#
# Warning: trajectory cut off by epoch at 290 steps.
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |               0 |
# |      AverageEpRet |           -12.8 |
# |          StdEpRet |            11.9 |
# |          MaxEpRet |            -0.9 |
# |          MinEpRet |           -60.5 |
# |             EpLen |             139 |
# |      AverageVVals |          0.0178 |
# |          StdVVals |          0.0344 |
# |          MaxVVals |          0.0884 |
# |          MinVVals |          -0.047 |
# | TotalEnvInteracts |           5e+03 |
# |            LossPi |        -1.3e-08 |
# |             LossV |            36.9 |
# |       DeltaLossPi |         -0.0192 |
# |        DeltaLossV |           -23.4 |
# |           Entropy |             1.6 |
# |                KL |          0.0116 |
# |          ClipFrac |           0.194 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |           -3.89 |
# |      StdVal_EpRet |            2.54 |
# |      MaxVal_EpRet |           -0.82 |
# |      MinVal_EpRet |           -7.84 |
# |  AverageVal_EpLen |            70.7 |
# |      StdVal_EpLen |            50.6 |
# |      MaxVal_EpLen |             163 |
# |      MinVal_EpLen |              19 |
# |              Time |            2.84 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 6 steps.
# Early stopping at step 46 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |           -5.65 |
# |          StdEpRet |            5.38 |
# |          MaxEpRet |             0.2 |
# |          MinEpRet |           -20.3 |
# |             EpLen |            67.5 |
# |      AverageVVals |           -3.65 |
# |          StdVVals |           0.563 |
# |          MaxVVals |           -2.69 |
# |          MinVVals |            -4.7 |
# | TotalEnvInteracts |           1e+04 |
# |            LossPi |       -4.58e-09 |
# |             LossV |            8.23 |
# |       DeltaLossPi |         -0.0228 |
# |        DeltaLossV |          -0.903 |
# |           Entropy |            1.59 |
# |                KL |          0.0157 |
# |          ClipFrac |           0.143 |
# |          StopIter |              46 |
# |  AverageVal_EpRet |           -2.12 |
# |      StdVal_EpRet |            1.02 |
# |      MaxVal_EpRet |           -0.25 |
# |      MinVal_EpRet |           -3.67 |
# |  AverageVal_EpLen |            35.1 |
# |      StdVal_EpLen |            13.1 |
# |      MaxVal_EpLen |              56 |
# |      MinVal_EpLen |              13 |
# |              Time |            4.97 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 53 steps.
# Early stopping at step 28 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |           -2.56 |
# |          StdEpRet |            2.53 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |           -15.4 |
# |             EpLen |            36.6 |
# |      AverageVVals |           -2.91 |
# |          StdVVals |           0.338 |
# |          MaxVVals |           -2.27 |
# |          MinVVals |           -3.64 |
# | TotalEnvInteracts |         1.5e+04 |
# |            LossPi |        2.31e-08 |
# |             LossV |            5.95 |
# |       DeltaLossPi |         -0.0248 |
# |        DeltaLossV |           -2.61 |
# |           Entropy |            1.55 |
# |                KL |          0.0152 |
# |          ClipFrac |           0.258 |
# |          StopIter |              28 |
# |  AverageVal_EpRet |           -1.16 |
# |      StdVal_EpRet |            1.03 |
# |      MaxVal_EpRet |         -0.0518 |
# |      MinVal_EpRet |           -3.34 |
# |  AverageVal_EpLen |            23.5 |
# |      StdVal_EpLen |            12.4 |
# |      MaxVal_EpLen |              51 |
# |      MinVal_EpLen |              11 |
# |              Time |            7.02 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 1 steps.
# Early stopping at step 21 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |           -1.41 |
# |          StdEpRet |            1.37 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -7.6 |
# |             EpLen |            25.1 |
# |      AverageVVals |           -1.42 |
# |          StdVVals |           0.151 |
# |          MaxVVals |            -1.1 |
# |          MinVVals |           -1.83 |
# | TotalEnvInteracts |           2e+04 |
# |            LossPi |        6.29e-09 |
# |             LossV |            2.14 |
# |       DeltaLossPi |         -0.0276 |
# |        DeltaLossV |          -0.843 |
# |           Entropy |             1.5 |
# |                KL |          0.0153 |
# |          ClipFrac |           0.103 |
# |          StopIter |              21 |
# |  AverageVal_EpRet |          -0.734 |
# |      StdVal_EpRet |           0.621 |
# |      MaxVal_EpRet |          0.0487 |
# |      MinVal_EpRet |           -2.18 |
# |  AverageVal_EpLen |            18.3 |
# |      StdVal_EpLen |            6.94 |
# |      MaxVal_EpLen |              35 |
# |      MinVal_EpLen |              10 |
# |              Time |            9.04 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 13 steps.
# Early stopping at step 22 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |          -0.811 |
# |          StdEpRet |           0.727 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -3.9 |
# |             EpLen |            19.1 |
# |      AverageVVals |          -0.678 |
# |          StdVVals |           0.138 |
# |          MaxVVals |          -0.479 |
# |          MinVVals |          -0.961 |
# | TotalEnvInteracts |         2.5e+04 |
# |            LossPi |        2.73e-08 |
# |             LossV |           0.858 |
# |       DeltaLossPi |         -0.0255 |
# |        DeltaLossV |          -0.369 |
# |           Entropy |            1.42 |
# |                KL |          0.0158 |
# |          ClipFrac |           0.281 |
# |          StopIter |              22 |
# |  AverageVal_EpRet |           -0.38 |
# |      StdVal_EpRet |           0.537 |
# |      MaxVal_EpRet |          0.0487 |
# |      MinVal_EpRet |           -1.53 |
# |  AverageVal_EpLen |            14.5 |
# |      StdVal_EpLen |            5.77 |
# |      MaxVal_EpLen |              27 |
# |      MinVal_EpLen |              10 |
# |              Time |            11.1 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 13 steps.
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |          -0.439 |
# |          StdEpRet |           0.587 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -3.1 |
# |             EpLen |            15.4 |
# |      AverageVVals |          -0.252 |
# |          StdVVals |           0.169 |
# |          MaxVVals |         -0.0668 |
# |          MinVVals |           -0.66 |
# | TotalEnvInteracts |           3e+04 |
# |            LossPi |        3.67e-09 |
# |             LossV |           0.464 |
# |       DeltaLossPi |         -0.0293 |
# |        DeltaLossV |         -0.0984 |
# |           Entropy |            1.31 |
# |                KL |          0.0128 |
# |          ClipFrac |             0.2 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |           -0.41 |
# |      StdVal_EpRet |           0.321 |
# |      MaxVal_EpRet |          0.0487 |
# |      MinVal_EpRet |              -1 |
# |  AverageVal_EpLen |            14.7 |
# |      StdVal_EpLen |            3.35 |
# |      MaxVal_EpLen |              21 |
# |      MinVal_EpLen |              10 |
# |              Time |            13.3 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 4 steps.
# Early stopping at step 68 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |           -0.25 |
# |          StdEpRet |           0.417 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -2.5 |
# |             EpLen |            13.5 |
# |      AverageVVals |         -0.0842 |
# |          StdVVals |           0.169 |
# |          MaxVVals |          0.0731 |
# |          MinVVals |          -0.513 |
# | TotalEnvInteracts |         3.5e+04 |
# |            LossPi |       -1.83e-08 |
# |             LossV |           0.312 |
# |       DeltaLossPi |         -0.0277 |
# |        DeltaLossV |         -0.0453 |
# |           Entropy |             1.2 |
# |                KL |          0.0152 |
# |          ClipFrac |           0.161 |
# |          StopIter |              68 |
# |  AverageVal_EpRet |           -0.17 |
# |      StdVal_EpRet |           0.444 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |           -1.27 |
# |  AverageVal_EpLen |            12.3 |
# |      StdVal_EpLen |            4.65 |
# |      MaxVal_EpLen |              24 |
# |      MinVal_EpLen |               8 |
# |              Time |            15.4 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 2 steps.
# Early stopping at step 21 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |         -0.0623 |
# |          StdEpRet |           0.303 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -1.3 |
# |             EpLen |            11.6 |
# |      AverageVVals |        0.000996 |
# |          StdVVals |           0.152 |
# |          MaxVVals |           0.121 |
# |          MinVVals |           -0.41 |
# | TotalEnvInteracts |           4e+04 |
# |            LossPi |        1.64e-08 |
# |             LossV |           0.268 |
# |       DeltaLossPi |         -0.0225 |
# |        DeltaLossV |         -0.0361 |
# |           Entropy |             1.1 |
# |                KL |          0.0156 |
# |          ClipFrac |           0.347 |
# |          StopIter |              21 |
# |  AverageVal_EpRet |         -0.0679 |
# |      StdVal_EpRet |           0.275 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.539 |
# |  AverageVal_EpLen |            11.2 |
# |      StdVal_EpLen |            2.79 |
# |      MaxVal_EpLen |              16 |
# |      MinVal_EpLen |               8 |
# |              Time |            17.5 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 5 steps.
# Early stopping at step 16 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |         -0.0275 |
# |          StdEpRet |           0.282 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -1.4 |
# |             EpLen |            11.3 |
# |      AverageVVals |          0.0706 |
# |          StdVVals |           0.124 |
# |          MaxVVals |            0.16 |
# |          MinVVals |          -0.303 |
# | TotalEnvInteracts |         4.5e+04 |
# |            LossPi |        5.74e-08 |
# |             LossV |           0.234 |
# |       DeltaLossPi |         -0.0187 |
# |        DeltaLossV |          -0.141 |
# |           Entropy |            1.03 |
# |                KL |          0.0167 |
# |          ClipFrac |           0.242 |
# |          StopIter |              16 |
# |  AverageVal_EpRet |        -0.00212 |
# |      StdVal_EpRet |           0.425 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |           -1.18 |
# |  AverageVal_EpLen |            10.6 |
# |      StdVal_EpLen |            4.43 |
# |      MaxVal_EpLen |              23 |
# |      MinVal_EpLen |               8 |
# |              Time |            19.5 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 4 steps.
# Early stopping at step 21 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |          0.0325 |
# |          StdEpRet |           0.255 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -1.6 |
# |             EpLen |            10.7 |
# |      AverageVVals |           0.421 |
# |          StdVVals |           0.187 |
# |          MaxVVals |           0.669 |
# |          MinVVals |         -0.0945 |
# | TotalEnvInteracts |           5e+04 |
# |            LossPi |        9.92e-09 |
# |             LossV |          0.0768 |
# |       DeltaLossPi |         -0.0243 |
# |        DeltaLossV |         -0.0109 |
# |           Entropy |           0.957 |
# |                KL |          0.0155 |
# |          ClipFrac |           0.249 |
# |          StopIter |              21 |
# |  AverageVal_EpRet |         -0.0494 |
# |      StdVal_EpRet |           0.217 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.539 |
# |  AverageVal_EpLen |              11 |
# |      StdVal_EpLen |            2.19 |
# |      MaxVal_EpLen |              16 |
# |      MinVal_EpLen |               8 |
# |              Time |            21.6 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |          0.0733 |
# |          StdEpRet |           0.253 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -1.7 |
# |             EpLen |            10.3 |
# |      AverageVVals |           0.469 |
# |          StdVVals |           0.251 |
# |          MaxVVals |           0.796 |
# |          MinVVals |          -0.157 |
# | TotalEnvInteracts |         5.5e+04 |
# |            LossPi |        -4.2e-09 |
# |             LossV |           0.072 |
# |       DeltaLossPi |         -0.0251 |
# |        DeltaLossV |         -0.0023 |
# |           Entropy |             0.9 |
# |                KL |         0.00872 |
# |          ClipFrac |           0.139 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |           0.172 |
# |      StdVal_EpRet |           0.134 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.151 |
# |  AverageVal_EpLen |             8.8 |
# |      StdVal_EpLen |            1.33 |
# |      MaxVal_EpLen |              12 |
# |      MinVal_EpLen |               8 |
# |              Time |              24 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 2 steps.
# Early stopping at step 18 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |           0.112 |
# |          StdEpRet |           0.191 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.6 |
# |             EpLen |            9.88 |
# |      AverageVVals |           0.459 |
# |          StdVVals |           0.264 |
# |          MaxVVals |            0.82 |
# |          MinVVals |           -0.18 |
# | TotalEnvInteracts |           6e+04 |
# |            LossPi |       -8.87e-09 |
# |             LossV |          0.0389 |
# |       DeltaLossPi |         -0.0222 |
# |        DeltaLossV |        -0.00302 |
# |           Entropy |            0.85 |
# |                KL |          0.0152 |
# |          ClipFrac |           0.202 |
# |          StopIter |              18 |
# |  AverageVal_EpRet |            0.14 |
# |      StdVal_EpRet |          0.0959 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |         -0.0518 |
# |  AverageVal_EpLen |             9.1 |
# |      StdVal_EpLen |           0.943 |
# |      MaxVal_EpLen |              11 |
# |      MinVal_EpLen |               8 |
# |              Time |              26 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 9 steps.
# Early stopping at step 15 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |           0.121 |
# |          StdEpRet |           0.196 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.7 |
# |             EpLen |            9.79 |
# |      AverageVVals |           0.524 |
# |          StdVVals |           0.284 |
# |          MaxVVals |             0.9 |
# |          MinVVals |          -0.162 |
# | TotalEnvInteracts |         6.5e+04 |
# |            LossPi |        5.91e-09 |
# |             LossV |          0.0448 |
# |       DeltaLossPi |         -0.0254 |
# |        DeltaLossV |         -0.0022 |
# |           Entropy |           0.814 |
# |                KL |          0.0152 |
# |          ClipFrac |           0.198 |
# |          StopIter |              15 |
# |  AverageVal_EpRet |          0.0401 |
# |      StdVal_EpRet |           0.171 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |           -0.25 |
# |  AverageVal_EpLen |            10.1 |
# |      StdVal_EpLen |             1.7 |
# |      MaxVal_EpLen |              13 |
# |      MinVal_EpLen |               8 |
# |              Time |              28 |
# ---------------------------------------
# Early stopping at step 24 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |           0.146 |
# |          StdEpRet |           0.171 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.7 |
# |             EpLen |            9.54 |
# |      AverageVVals |           0.498 |
# |          StdVVals |           0.271 |
# |          MaxVVals |           0.863 |
# |          MinVVals |          -0.156 |
# | TotalEnvInteracts |           7e+04 |
# |            LossPi |        1.79e-08 |
# |             LossV |          0.0345 |
# |       DeltaLossPi |         -0.0201 |
# |        DeltaLossV |        -0.00145 |
# |           Entropy |           0.777 |
# |                KL |          0.0163 |
# |          ClipFrac |           0.168 |
# |          StopIter |              24 |
# |  AverageVal_EpRet |            0.12 |
# |      StdVal_EpRet |           0.111 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.151 |
# |  AverageVal_EpLen |             9.3 |
# |      StdVal_EpLen |             1.1 |
# |      MaxVal_EpLen |              12 |
# |      MinVal_EpLen |               8 |
# |              Time |            30.1 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 8 steps.
# Early stopping at step 21 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |           0.163 |
# |          StdEpRet |           0.165 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.5 |
# |             EpLen |            9.37 |
# |      AverageVVals |           0.532 |
# |          StdVVals |           0.274 |
# |          MaxVVals |           0.909 |
# |          MinVVals |          -0.115 |
# | TotalEnvInteracts |         7.5e+04 |
# |            LossPi |       -1.43e-09 |
# |             LossV |          0.0313 |
# |       DeltaLossPi |          -0.019 |
# |        DeltaLossV |       -0.000862 |
# |           Entropy |           0.752 |
# |                KL |          0.0156 |
# |          ClipFrac |           0.378 |
# |          StopIter |              21 |
# |  AverageVal_EpRet |           0.131 |
# |      StdVal_EpRet |           0.148 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |           -0.25 |
# |  AverageVal_EpLen |             9.2 |
# |      StdVal_EpLen |            1.47 |
# |      MaxVal_EpLen |              13 |
# |      MinVal_EpLen |               8 |
# |              Time |            32.1 |
# ---------------------------------------
# Early stopping at step 16 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |           0.167 |
# |          StdEpRet |           0.157 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.7 |
# |             EpLen |            9.33 |
# |      AverageVVals |           0.535 |
# |          StdVVals |           0.265 |
# |          MaxVVals |           0.898 |
# |          MinVVals |         -0.0958 |
# | TotalEnvInteracts |           8e+04 |
# |            LossPi |        8.96e-09 |
# |             LossV |            0.03 |
# |       DeltaLossPi |         -0.0194 |
# |        DeltaLossV |       -0.000748 |
# |           Entropy |           0.721 |
# |                KL |          0.0162 |
# |          ClipFrac |             0.2 |
# |          StopIter |              16 |
# |  AverageVal_EpRet |          0.0699 |
# |      StdVal_EpRet |           0.142 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.151 |
# |  AverageVal_EpLen |             9.8 |
# |      StdVal_EpLen |             1.4 |
# |      MaxVal_EpLen |              12 |
# |      MinVal_EpLen |               8 |
# |              Time |            34.2 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 3 steps.
# Early stopping at step 19 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |           0.186 |
# |          StdEpRet |           0.161 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.8 |
# |             EpLen |            9.14 |
# |      AverageVVals |           0.542 |
# |          StdVVals |            0.27 |
# |          MaxVVals |           0.924 |
# |          MinVVals |         -0.0784 |
# | TotalEnvInteracts |         8.5e+04 |
# |            LossPi |       -6.77e-09 |
# |             LossV |          0.0299 |
# |       DeltaLossPi |         -0.0197 |
# |        DeltaLossV |       -0.000768 |
# |           Entropy |           0.714 |
# |                KL |          0.0153 |
# |          ClipFrac |            0.24 |
# |          StopIter |              19 |
# |  AverageVal_EpRet |           0.171 |
# |      StdVal_EpRet |          0.0613 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          0.0487 |
# |  AverageVal_EpLen |             8.8 |
# |      StdVal_EpLen |             0.6 |
# |      MaxVal_EpLen |              10 |
# |      MinVal_EpLen |               8 |
# |              Time |            36.2 |
# ---------------------------------------
# Logging data to ./outputs/grid_qbe_oracle_revealed/seed=1/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             32,
#             32
#         ]
#     },
#     "actor_critic":	"MLPActorCritic",
#     "clip_ratio":	0.2,
#     "env_fn":	"<function <lambda> at 0x7efaf647e710>",
#     "epochs":	50,
#     "exp_name":	"MyGridNaviCoords-v1_ppo",
#     "gamma":	0.99,
#     "lam":	0.97,
#     "logger":	{
#         "<offsim4rl.agents.spinup.utils.logx.EpochLogger object at 0x7efb6ad7b5d0>":	{
#             "epoch_dict":	{},
#             "exp_name":	"MyGridNaviCoords-v1_ppo",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"./outputs/grid_qbe_oracle_revealed/seed=1",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='./outputs/grid_qbe_oracle_revealed/seed=1/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"MyGridNaviCoords-v1_ppo",
#         "output_dir":	"./outputs/grid_qbe_oracle_revealed/seed=1"
#     },
#     "max_ep_len":	1000,
#     "pi_lr":	0.0003,
#     "save_freq":	10,
#     "seed":	1,
#     "steps_per_epoch":	5000,
#     "target_kl":	0.01,
#     "train_pi_iters":	80,
#     "train_v_iters":	80,
#     "val_kwargs":	{
#         "val_env_fn":	"<function <lambda> at 0x7efaf647ec20>",
#         "val_n_episodes":	10
#     },
#     "validate":	true,
#     "vf_lr":	0.001
# }
#
# Number of parameters: 	 pi: 1317, 	 v: 1185
#
# Warning: trajectory cut off by epoch at 51 steps.
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |               0 |
# |      AverageEpRet |           -11.6 |
# |          StdEpRet |            11.3 |
# |          MaxEpRet |            -0.8 |
# |          MinEpRet |           -56.1 |
# |             EpLen |             127 |
# |      AverageVVals |         -0.0641 |
# |          StdVVals |          0.0417 |
# |          MaxVVals |          0.0185 |
# |          MinVVals |          -0.146 |
# | TotalEnvInteracts |           5e+03 |
# |            LossPi |       -1.39e-07 |
# |             LossV |            33.1 |
# |       DeltaLossPi |         -0.0221 |
# |        DeltaLossV |           -15.4 |
# |           Entropy |            1.61 |
# |                KL |          0.0118 |
# |          ClipFrac |           0.109 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |           -2.62 |
# |      StdVal_EpRet |            2.09 |
# |      MaxVal_EpRet |           -0.25 |
# |      MinVal_EpRet |           -5.97 |
# |  AverageVal_EpLen |            45.4 |
# |      StdVal_EpLen |            31.9 |
# |      MaxVal_EpLen |             101 |
# |      MinVal_EpLen |              13 |
# |              Time |             2.4 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 15 steps.
# Early stopping at step 58 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |           -4.04 |
# |          StdEpRet |            3.54 |
# |          MaxEpRet |       -1.49e-08 |
# |          MinEpRet |           -18.6 |
# |             EpLen |            51.4 |
# |      AverageVVals |           -2.38 |
# |          StdVVals |           0.351 |
# |          MaxVVals |           -1.82 |
# |          MinVVals |           -3.26 |
# | TotalEnvInteracts |           1e+04 |
# |            LossPi |        3.15e-09 |
# |             LossV |            5.54 |
# |       DeltaLossPi |         -0.0268 |
# |        DeltaLossV |          -0.536 |
# |           Entropy |            1.59 |
# |                KL |          0.0152 |
# |          ClipFrac |            0.18 |
# |          StopIter |              58 |
# |  AverageVal_EpRet |           -1.89 |
# |      StdVal_EpRet |            1.62 |
# |      MaxVal_EpRet |          -0.347 |
# |      MinVal_EpRet |           -5.85 |
# |  AverageVal_EpLen |            33.9 |
# |      StdVal_EpLen |            24.4 |
# |      MaxVal_EpLen |              98 |
# |      MinVal_EpLen |              14 |
# |              Time |            4.56 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 2 steps.
# Early stopping at step 34 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |           -2.23 |
# |          StdEpRet |            1.67 |
# |          MaxEpRet |             0.1 |
# |          MinEpRet |            -8.6 |
# |             EpLen |            33.3 |
# |      AverageVVals |           -2.01 |
# |          StdVVals |           0.138 |
# |          MaxVVals |           -1.76 |
# |          MinVVals |           -2.33 |
# | TotalEnvInteracts |         1.5e+04 |
# |            LossPi |        8.77e-09 |
# |             LossV |            3.25 |
# |       DeltaLossPi |         -0.0252 |
# |        DeltaLossV |           -1.42 |
# |           Entropy |            1.54 |
# |                KL |           0.015 |
# |          ClipFrac |           0.201 |
# |          StopIter |              34 |
# |  AverageVal_EpRet |           -1.01 |
# |      StdVal_EpRet |            1.14 |
# |      MaxVal_EpRet |          0.0487 |
# |      MinVal_EpRet |           -3.67 |
# |  AverageVal_EpLen |              22 |
# |      StdVal_EpLen |            13.8 |
# |      MaxVal_EpLen |              56 |
# |      MinVal_EpLen |              10 |
# |              Time |            6.64 |
# ---------------------------------------
# Early stopping at step 21 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |           -1.21 |
# |          StdEpRet |            1.08 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -6.5 |
# |             EpLen |            23.1 |
# |      AverageVVals |           -1.06 |
# |          StdVVals |          0.0748 |
# |          MaxVVals |          -0.951 |
# |          MinVVals |            -1.2 |
# | TotalEnvInteracts |           2e+04 |
# |            LossPi |        4.58e-09 |
# |             LossV |            1.46 |
# |       DeltaLossPi |         -0.0263 |
# |        DeltaLossV |          -0.556 |
# |           Entropy |            1.47 |
# |                KL |          0.0152 |
# |          ClipFrac |             0.2 |
# |          StopIter |              21 |
# |  AverageVal_EpRet |          -0.364 |
# |      StdVal_EpRet |            0.48 |
# |      MaxVal_EpRet |            0.15 |
# |      MinVal_EpRet |           -1.44 |
# |  AverageVal_EpLen |            14.3 |
# |      StdVal_EpLen |             5.1 |
# |      MaxVal_EpLen |              26 |
# |      MinVal_EpLen |               9 |
# |              Time |            8.65 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 8 steps.
# Early stopping at step 23 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |          -0.658 |
# |          StdEpRet |           0.649 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -3.3 |
# |             EpLen |            17.6 |
# |      AverageVVals |          -0.545 |
# |          StdVVals |           0.198 |
# |          MaxVVals |           -0.24 |
# |          MinVVals |          -0.907 |
# | TotalEnvInteracts |         2.5e+04 |
# |            LossPi |        5.97e-08 |
# |             LossV |           0.677 |
# |       DeltaLossPi |         -0.0268 |
# |        DeltaLossV |          -0.361 |
# |           Entropy |            1.39 |
# |                KL |          0.0153 |
# |          ClipFrac |           0.268 |
# |          StopIter |              23 |
# |  AverageVal_EpRet |           -0.41 |
# |      StdVal_EpRet |           0.298 |
# |      MaxVal_EpRet |          0.0487 |
# |      MinVal_EpRet |           -1.09 |
# |  AverageVal_EpLen |            14.7 |
# |      StdVal_EpLen |            3.13 |
# |      MaxVal_EpLen |              22 |
# |      MinVal_EpLen |              10 |
# |              Time |            10.7 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 3 steps.
# Early stopping at step 22 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |          -0.396 |
# |          StdEpRet |           0.542 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -2.9 |
# |             EpLen |              15 |
# |      AverageVVals |          0.0597 |
# |          StdVVals |           0.329 |
# |          MaxVVals |           0.493 |
# |          MinVVals |          -0.576 |
# | TotalEnvInteracts |           3e+04 |
# |            LossPi |       -2.29e-09 |
# |             LossV |           0.246 |
# |       DeltaLossPi |         -0.0254 |
# |        DeltaLossV |         -0.0176 |
# |           Entropy |            1.27 |
# |                KL |          0.0157 |
# |          ClipFrac |           0.208 |
# |          StopIter |              22 |
# |  AverageVal_EpRet |          -0.156 |
# |      StdVal_EpRet |           0.319 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.634 |
# |  AverageVal_EpLen |            12.1 |
# |      StdVal_EpLen |            3.24 |
# |      MaxVal_EpLen |              17 |
# |      MinVal_EpLen |               8 |
# |              Time |            12.7 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 2 steps.
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |          -0.205 |
# |          StdEpRet |            0.39 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -2.2 |
# |             EpLen |              13 |
# |      AverageVVals |           0.185 |
# |          StdVVals |           0.372 |
# |          MaxVVals |           0.694 |
# |          MinVVals |          -0.517 |
# | TotalEnvInteracts |         3.5e+04 |
# |            LossPi |       -3.19e-09 |
# |             LossV |           0.142 |
# |       DeltaLossPi |         -0.0271 |
# |        DeltaLossV |         -0.0162 |
# |           Entropy |            1.15 |
# |                KL |         0.00612 |
# |          ClipFrac |           0.112 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |         -0.0827 |
# |      StdVal_EpRet |           0.414 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |           -1.09 |
# |  AverageVal_EpLen |            11.4 |
# |      StdVal_EpLen |            4.29 |
# |      MaxVal_EpLen |              22 |
# |      MinVal_EpLen |               8 |
# |              Time |            14.9 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 7 steps.
# Early stopping at step 28 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |         -0.0888 |
# |          StdEpRet |           0.346 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -1.8 |
# |             EpLen |            11.9 |
# |      AverageVVals |           0.284 |
# |          StdVVals |           0.368 |
# |          MaxVVals |           0.823 |
# |          MinVVals |          -0.379 |
# | TotalEnvInteracts |           4e+04 |
# |            LossPi |       -1.67e-08 |
# |             LossV |           0.105 |
# |       DeltaLossPi |         -0.0251 |
# |        DeltaLossV |         -0.0099 |
# |           Entropy |            1.07 |
# |                KL |          0.0156 |
# |          ClipFrac |           0.111 |
# |          StopIter |              28 |
# |  AverageVal_EpRet |         -0.0165 |
# |      StdVal_EpRet |           0.315 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.912 |
# |  AverageVal_EpLen |            10.7 |
# |      StdVal_EpLen |            3.26 |
# |      MaxVal_EpLen |              20 |
# |      MinVal_EpLen |               8 |
# |              Time |              17 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 9 steps.
# Early stopping at step 22 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |         -0.0141 |
# |          StdEpRet |           0.276 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -1.3 |
# |             EpLen |            11.1 |
# |      AverageVVals |           0.376 |
# |          StdVVals |           0.351 |
# |          MaxVVals |           0.906 |
# |          MinVVals |          -0.248 |
# | TotalEnvInteracts |         4.5e+04 |
# |            LossPi |       -1.34e-09 |
# |             LossV |          0.0687 |
# |       DeltaLossPi |         -0.0308 |
# |        DeltaLossV |        -0.00575 |
# |           Entropy |           0.975 |
# |                KL |          0.0169 |
# |          ClipFrac |           0.335 |
# |          StopIter |              22 |
# |  AverageVal_EpRet |         -0.0278 |
# |      StdVal_EpRet |           0.279 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.634 |
# |  AverageVal_EpLen |            10.8 |
# |      StdVal_EpLen |            2.82 |
# |      MaxVal_EpLen |              17 |
# |      MinVal_EpLen |               8 |
# |              Time |              19 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 7 steps.
# Early stopping at step 29 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |          0.0422 |
# |          StdEpRet |           0.251 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |              -1 |
# |             EpLen |            10.6 |
# |      AverageVVals |           0.422 |
# |          StdVVals |           0.329 |
# |          MaxVVals |           0.922 |
# |          MinVVals |           -0.15 |
# | TotalEnvInteracts |           5e+04 |
# |            LossPi |        1.37e-08 |
# |             LossV |           0.059 |
# |       DeltaLossPi |         -0.0262 |
# |        DeltaLossV |        -0.00314 |
# |           Entropy |           0.916 |
# |                KL |          0.0164 |
# |          ClipFrac |            0.33 |
# |          StopIter |              29 |
# |  AverageVal_EpRet |           0.121 |
# |      StdVal_EpRet |           0.136 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.151 |
# |  AverageVal_EpLen |             9.3 |
# |      StdVal_EpLen |            1.35 |
# |      MaxVal_EpLen |              12 |
# |      MinVal_EpLen |               8 |
# |              Time |            21.1 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# Early stopping at step 23 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |          0.0775 |
# |          StdEpRet |           0.225 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |              -1 |
# |             EpLen |            10.2 |
# |      AverageVVals |            0.46 |
# |          StdVVals |           0.304 |
# |          MaxVVals |           0.927 |
# |          MinVVals |         -0.0629 |
# | TotalEnvInteracts |         5.5e+04 |
# |            LossPi |       -1.77e-08 |
# |             LossV |          0.0489 |
# |       DeltaLossPi |         -0.0266 |
# |        DeltaLossV |        -0.00192 |
# |           Entropy |           0.858 |
# |                KL |           0.015 |
# |          ClipFrac |           0.318 |
# |          StopIter |              23 |
# |  AverageVal_EpRet |         -0.0488 |
# |      StdVal_EpRet |           0.244 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.444 |
# |  AverageVal_EpLen |              11 |
# |      StdVal_EpLen |            2.45 |
# |      MaxVal_EpLen |              15 |
# |      MinVal_EpLen |               8 |
# |              Time |            23.6 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 1 steps.
# Early stopping at step 24 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |          0.0982 |
# |          StdEpRet |           0.206 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.8 |
# |             EpLen |              10 |
# |      AverageVVals |           0.485 |
# |          StdVVals |           0.291 |
# |          MaxVVals |           0.937 |
# |          MinVVals |        -0.00907 |
# | TotalEnvInteracts |           6e+04 |
# |            LossPi |       -8.39e-09 |
# |             LossV |          0.0396 |
# |       DeltaLossPi |         -0.0263 |
# |        DeltaLossV |       -0.000577 |
# |           Entropy |           0.829 |
# |                KL |          0.0161 |
# |          ClipFrac |           0.322 |
# |          StopIter |              24 |
# |  AverageVal_EpRet |        0.000956 |
# |      StdVal_EpRet |           0.228 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.444 |
# |  AverageVal_EpLen |            10.5 |
# |      StdVal_EpLen |            2.29 |
# |      MaxVal_EpLen |              15 |
# |      MinVal_EpLen |               8 |
# |              Time |            25.6 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 8 steps.
# Early stopping at step 22 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |           0.113 |
# |          StdEpRet |            0.21 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -1.4 |
# |             EpLen |            9.87 |
# |      AverageVVals |           0.497 |
# |          StdVVals |           0.284 |
# |          MaxVVals |           0.949 |
# |          MinVVals |          0.0191 |
# | TotalEnvInteracts |         6.5e+04 |
# |            LossPi |        5.77e-09 |
# |             LossV |          0.0436 |
# |       DeltaLossPi |          -0.027 |
# |        DeltaLossV |       -0.000571 |
# |           Entropy |           0.794 |
# |                KL |          0.0165 |
# |          ClipFrac |           0.347 |
# |          StopIter |              22 |
# |  AverageVal_EpRet |          0.0606 |
# |      StdVal_EpRet |           0.187 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.347 |
# |  AverageVal_EpLen |             9.9 |
# |      StdVal_EpLen |            1.87 |
# |      MaxVal_EpLen |              14 |
# |      MinVal_EpLen |               8 |
# |              Time |            27.7 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 7 steps.
# Early stopping at step 21 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |            0.14 |
# |          StdEpRet |           0.162 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.4 |
# |             EpLen |             9.6 |
# |      AverageVVals |           0.499 |
# |          StdVVals |           0.276 |
# |          MaxVVals |           0.935 |
# |          MinVVals |          0.0455 |
# | TotalEnvInteracts |           7e+04 |
# |            LossPi |        -8.3e-09 |
# |             LossV |          0.0265 |
# |       DeltaLossPi |         -0.0286 |
# |        DeltaLossV |        -0.00115 |
# |           Entropy |           0.776 |
# |                KL |          0.0163 |
# |          ClipFrac |           0.249 |
# |          StopIter |              21 |
# |  AverageVal_EpRet |           0.141 |
# |      StdVal_EpRet |           0.124 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.151 |
# |  AverageVal_EpLen |             9.1 |
# |      StdVal_EpLen |            1.22 |
# |      MaxVal_EpLen |              12 |
# |      MinVal_EpLen |               8 |
# |              Time |            30.1 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 2 steps.
# Early stopping at step 27 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |           0.152 |
# |          StdEpRet |           0.173 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.7 |
# |             EpLen |            9.48 |
# |      AverageVVals |           0.526 |
# |          StdVVals |           0.276 |
# |          MaxVVals |           0.979 |
# |          MinVVals |          0.0759 |
# | TotalEnvInteracts |         7.5e+04 |
# |            LossPi |       -2.29e-09 |
# |             LossV |           0.029 |
# |       DeltaLossPi |         -0.0237 |
# |        DeltaLossV |       -0.000269 |
# |           Entropy |           0.755 |
# |                KL |          0.0156 |
# |          ClipFrac |           0.309 |
# |          StopIter |              27 |
# |  AverageVal_EpRet |           0.151 |
# |      StdVal_EpRet |           0.102 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |         -0.0518 |
# |  AverageVal_EpLen |               9 |
# |      StdVal_EpLen |               1 |
# |      MaxVal_EpLen |              11 |
# |      MinVal_EpLen |               8 |
# |              Time |            32.1 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 6 steps.
# Early stopping at step 21 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |           0.152 |
# |          StdEpRet |           0.171 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.9 |
# |             EpLen |            9.48 |
# |      AverageVVals |           0.532 |
# |          StdVVals |           0.271 |
# |          MaxVVals |           0.967 |
# |          MinVVals |          0.0928 |
# | TotalEnvInteracts |           8e+04 |
# |            LossPi |       -1.49e-08 |
# |             LossV |          0.0295 |
# |       DeltaLossPi |         -0.0242 |
# |        DeltaLossV |       -0.000311 |
# |           Entropy |           0.736 |
# |                KL |          0.0167 |
# |          ClipFrac |           0.297 |
# |          StopIter |              21 |
# |  AverageVal_EpRet |            0.11 |
# |      StdVal_EpRet |           0.137 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.151 |
# |  AverageVal_EpLen |             9.4 |
# |      StdVal_EpLen |            1.36 |
# |      MaxVal_EpLen |              12 |
# |      MinVal_EpLen |               8 |
# |              Time |            34.1 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 8 steps.
# Early stopping at step 18 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |            0.16 |
# |          StdEpRet |           0.166 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.8 |
# |             EpLen |             9.4 |
# |      AverageVVals |           0.531 |
# |          StdVVals |           0.267 |
# |          MaxVVals |           0.976 |
# |          MinVVals |           0.096 |
# | TotalEnvInteracts |         8.5e+04 |
# |            LossPi |        4.96e-09 |
# |             LossV |          0.0277 |
# |       DeltaLossPi |         -0.0307 |
# |        DeltaLossV |       -0.000628 |
# |           Entropy |           0.725 |
# |                KL |          0.0173 |
# |          ClipFrac |           0.212 |
# |          StopIter |              18 |
# |  AverageVal_EpRet |             0.1 |
# |      StdVal_EpRet |           0.113 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |         -0.0518 |
# |  AverageVal_EpLen |             9.5 |
# |      StdVal_EpLen |            1.12 |
# |      MaxVal_EpLen |              11 |
# |      MinVal_EpLen |               8 |
# |              Time |            36.2 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 10 steps.
# Early stopping at step 24 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |           0.176 |
# |          StdEpRet |           0.162 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |              -1 |
# |             EpLen |            9.24 |
# |      AverageVVals |           0.535 |
# |          StdVVals |            0.27 |
# |          MaxVVals |           0.975 |
# |          MinVVals |           0.103 |
# | TotalEnvInteracts |           9e+04 |
# |            LossPi |        3.05e-09 |
# |             LossV |          0.0277 |
# |       DeltaLossPi |         -0.0238 |
# |        DeltaLossV |       -0.000456 |
# |           Entropy |           0.719 |
# |                KL |          0.0158 |
# |          ClipFrac |           0.195 |
# |          StopIter |              24 |
# |  AverageVal_EpRet |           0.131 |
# ...
# |            LossPi |       -1.14e-09 |
# |             LossV |           0.357 |
# |       DeltaLossPi |         -0.0341 |
# |        DeltaLossV |         -0.0497 |
# |           Entropy |            1.38 |
# |                KL |          0.0152 |
# |          ClipFrac |           0.197 |
# |          StopIter |              16 |
# |  AverageVal_EpRet |           -0.57 |
# |      StdVal_EpRet |           0.352 |
# |      MaxVal_EpRet |           -0.25 |
# |      MinVal_EpRet |           -1.53 |
# |  AverageVal_EpLen |            16.4 |
# |      StdVal_EpLen |            3.85 |
# |      MaxVal_EpLen |              27 |
# |      MinVal_EpLen |              13 |
# |              Time |            10.3 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 1 steps.
# Early stopping at step 18 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |          -0.308 |
# |          StdEpRet |           0.474 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -2.7 |
# |             EpLen |            14.1 |
# |      AverageVVals |            0.04 |
# |          StdVVals |           0.407 |
# |          MaxVVals |            0.78 |
# |          MinVVals |           -0.63 |
# | TotalEnvInteracts |           3e+04 |
# |            LossPi |       -1.24e-08 |
# |             LossV |           0.207 |
# |       DeltaLossPi |         -0.0305 |
# |        DeltaLossV |         -0.0371 |
# |           Entropy |            1.27 |
# |                KL |          0.0161 |
# |          ClipFrac |           0.193 |
# |          StopIter |              18 |
# |  AverageVal_EpRet |          -0.127 |
# |      StdVal_EpRet |           0.288 |
# |      MaxVal_EpRet |            0.15 |
# |      MinVal_EpRet |           -0.82 |
# |  AverageVal_EpLen |            11.8 |
# |      StdVal_EpLen |            2.96 |
# |      MaxVal_EpLen |              19 |
# |      MinVal_EpLen |               9 |
# |              Time |            12.3 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 8 steps.
# Early stopping at step 21 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |          -0.145 |
# |          StdEpRet |            0.34 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -1.7 |
# |             EpLen |            12.4 |
# |      AverageVVals |           0.236 |
# |          StdVVals |            0.42 |
# |          MaxVVals |            0.96 |
# |          MinVVals |          -0.479 |
# | TotalEnvInteracts |         3.5e+04 |
# |            LossPi |        5.44e-09 |
# |             LossV |           0.106 |
# |       DeltaLossPi |         -0.0254 |
# |        DeltaLossV |         -0.0173 |
# |           Entropy |            1.15 |
# |                KL |          0.0157 |
# |          ClipFrac |           0.148 |
# |          StopIter |              21 |
# |  AverageVal_EpRet |          -0.159 |
# |      StdVal_EpRet |           0.218 |
# |      MaxVal_EpRet |            0.15 |
# |      MinVal_EpRet |          -0.539 |
# |  AverageVal_EpLen |            12.1 |
# |      StdVal_EpLen |            2.21 |
# |      MaxVal_EpLen |              16 |
# |      MinVal_EpLen |               9 |
# |              Time |            14.3 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 15 steps.
# Early stopping at step 18 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |         -0.0127 |
# |          StdEpRet |           0.274 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |              -1 |
# |             EpLen |            11.1 |
# |      AverageVVals |           0.341 |
# |          StdVVals |           0.382 |
# |          MaxVVals |           0.986 |
# |          MinVVals |          -0.318 |
# | TotalEnvInteracts |           4e+04 |
# |            LossPi |        1.54e-08 |
# |             LossV |          0.0749 |
# |       DeltaLossPi |         -0.0337 |
# |        DeltaLossV |         -0.0117 |
# |           Entropy |            1.05 |
# |                KL |           0.015 |
# |          ClipFrac |           0.241 |
# |          StopIter |              18 |
# |  AverageVal_EpRet |         -0.0556 |
# |      StdVal_EpRet |           0.346 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |           -0.82 |
# |  AverageVal_EpLen |            11.1 |
# |      StdVal_EpLen |            3.53 |
# |      MaxVal_EpLen |              19 |
# |      MinVal_EpLen |               8 |
# |              Time |            16.2 |
# ---------------------------------------
# Early stopping at step 20 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |          0.0107 |
# |          StdEpRet |           0.266 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -1.5 |
# |             EpLen |            10.9 |
# |      AverageVVals |            0.43 |
# |          StdVVals |           0.353 |
# |          MaxVVals |            1.02 |
# |          MinVVals |          -0.185 |
# | TotalEnvInteracts |         4.5e+04 |
# |            LossPi |               0 |
# |             LossV |          0.0662 |
# |       DeltaLossPi |         -0.0327 |
# |        DeltaLossV |        -0.00532 |
# |           Entropy |           0.979 |
# |                KL |          0.0169 |
# |          ClipFrac |           0.391 |
# |          StopIter |              20 |
# |  AverageVal_EpRet |             0.1 |
# |      StdVal_EpRet |           0.151 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |           -0.25 |
# |  AverageVal_EpLen |             9.5 |
# |      StdVal_EpLen |             1.5 |
# |      MaxVal_EpLen |              13 |
# |      MinVal_EpLen |               8 |
# |              Time |            18.2 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 6 steps.
# Early stopping at step 29 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |          0.0508 |
# |          StdEpRet |           0.244 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |              -1 |
# |             EpLen |            10.5 |
# |      AverageVVals |           0.444 |
# |          StdVVals |           0.321 |
# |          MaxVVals |            0.98 |
# |          MinVVals |          -0.106 |
# | TotalEnvInteracts |           5e+04 |
# |            LossPi |        1.45e-08 |
# |             LossV |          0.0527 |
# |       DeltaLossPi |         -0.0284 |
# |        DeltaLossV |        -0.00167 |
# |           Entropy |           0.921 |
# |                KL |          0.0166 |
# |          ClipFrac |           0.248 |
# |          StopIter |              29 |
# |  AverageVal_EpRet |         -0.0296 |
# |      StdVal_EpRet |           0.209 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.347 |
# |  AverageVal_EpLen |            10.8 |
# |      StdVal_EpLen |            2.09 |
# |      MaxVal_EpLen |              14 |
# |      MinVal_EpLen |               8 |
# |              Time |            20.2 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 5 steps.
# Warning: could not pickle state_dict.
# Early stopping at step 21 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |          0.0909 |
# |          StdEpRet |           0.213 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.7 |
# |             EpLen |            10.1 |
# |      AverageVVals |            0.46 |
# |          StdVVals |           0.303 |
# |          MaxVVals |           0.967 |
# |          MinVVals |         -0.0295 |
# | TotalEnvInteracts |         5.5e+04 |
# |            LossPi |       -7.63e-10 |
# |             LossV |          0.0389 |
# |       DeltaLossPi |          -0.028 |
# |        DeltaLossV |        -0.00162 |
# |           Entropy |           0.863 |
# |                KL |          0.0168 |
# |          ClipFrac |           0.376 |
# |          StopIter |              21 |
# |  AverageVal_EpRet |          0.0103 |
# |      StdVal_EpRet |           0.196 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.347 |
# |  AverageVal_EpLen |            10.4 |
# |      StdVal_EpLen |            1.96 |
# |      MaxVal_EpLen |              14 |
# |      MinVal_EpLen |               8 |
# |              Time |            22.5 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 6 steps.
# Early stopping at step 23 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |           0.127 |
# |          StdEpRet |           0.187 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.7 |
# |             EpLen |            9.73 |
# |      AverageVVals |           0.493 |
# |          StdVVals |           0.289 |
# |          MaxVVals |           0.995 |
# |          MinVVals |          0.0204 |
# | TotalEnvInteracts |           6e+04 |
# |            LossPi |        1.65e-08 |
# |             LossV |          0.0336 |
# |       DeltaLossPi |         -0.0241 |
# |        DeltaLossV |        -0.00188 |
# |           Entropy |           0.823 |
# |                KL |          0.0153 |
# |          ClipFrac |           0.361 |
# |          StopIter |              23 |
# |  AverageVal_EpRet |          0.0801 |
# |      StdVal_EpRet |           0.143 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |           -0.25 |
# |  AverageVal_EpLen |             9.7 |
# |      StdVal_EpLen |            1.42 |
# |      MaxVal_EpLen |              13 |
# |      MinVal_EpLen |               8 |
# |              Time |            24.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |           0.149 |
# |          StdEpRet |           0.166 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.9 |
# |             EpLen |            9.51 |
# |      AverageVVals |           0.509 |
# |          StdVVals |           0.283 |
# |          MaxVVals |            1.01 |
# |          MinVVals |          0.0766 |
# | TotalEnvInteracts |         6.5e+04 |
# |            LossPi |       -1.69e-08 |
# |             LossV |          0.0297 |
# |       DeltaLossPi |         -0.0289 |
# |        DeltaLossV |       -0.000892 |
# |           Entropy |           0.795 |
# |                KL |         0.00837 |
# |          ClipFrac |           0.134 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |           0.131 |
# |      StdVal_EpRet |           0.134 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.151 |
# |  AverageVal_EpLen |             9.2 |
# |      StdVal_EpLen |            1.33 |
# |      MaxVal_EpLen |              12 |
# |      MinVal_EpLen |               8 |
# |              Time |            26.7 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 7 steps.
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |           0.175 |
# |          StdEpRet |           0.154 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.9 |
# |             EpLen |            9.25 |
# |      AverageVVals |           0.533 |
# |          StdVVals |           0.272 |
# |          MaxVVals |            1.01 |
# |          MinVVals |           0.075 |
# | TotalEnvInteracts |           7e+04 |
# |            LossPi |         1.6e-08 |
# |             LossV |          0.0239 |
# |       DeltaLossPi |         -0.0295 |
# |        DeltaLossV |       -0.000183 |
# |           Entropy |           0.756 |
# |                KL |         0.00676 |
# |          ClipFrac |           0.069 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |           0.201 |
# |      StdVal_EpRet |          0.0513 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |            0.15 |
# |  AverageVal_EpLen |             8.5 |
# |      StdVal_EpLen |             0.5 |
# |      MaxVal_EpLen |               9 |
# |      MinVal_EpLen |               8 |
# |              Time |            28.8 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 2 steps.
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |           0.212 |
# |          StdEpRet |           0.121 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.4 |
# |             EpLen |            8.88 |
# |      AverageVVals |            0.54 |
# |          StdVVals |           0.267 |
# |          MaxVVals |            1.01 |
# |          MinVVals |           0.104 |
# | TotalEnvInteracts |         7.5e+04 |
# |            LossPi |       -8.77e-09 |
# |             LossV |          0.0179 |
# |       DeltaLossPi |         -0.0218 |
# |        DeltaLossV |       -0.000961 |
# |           Entropy |           0.712 |
# |                KL |         0.00526 |
# |          ClipFrac |          0.0638 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |           0.161 |
# |      StdVal_EpRet |           0.124 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |         -0.0518 |
# |  AverageVal_EpLen |             8.9 |
# |      StdVal_EpLen |            1.22 |
# |      MaxVal_EpLen |              11 |
# |      MinVal_EpLen |               8 |
# |              Time |              31 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 2 steps.
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |           0.235 |
# |          StdEpRet |             0.1 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.4 |
# |             EpLen |            8.65 |
# |      AverageVVals |           0.563 |
# |          StdVVals |           0.255 |
# |          MaxVVals |            1.02 |
# |          MinVVals |           0.142 |
# | TotalEnvInteracts |           8e+04 |
# |            LossPi |        1.18e-08 |
# |             LossV |          0.0116 |
# |       DeltaLossPi |         -0.0208 |
# |        DeltaLossV |       -0.000474 |
# |           Entropy |           0.672 |
# |                KL |         0.00475 |
# |          ClipFrac |          0.0562 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |           0.192 |
# |      StdVal_EpRet |          0.0932 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |         -0.0518 |
# |  AverageVal_EpLen |             8.6 |
# |      StdVal_EpLen |           0.917 |
# |      MaxVal_EpLen |              11 |
# |      MinVal_EpLen |               8 |
# |              Time |            33.2 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 5 steps.
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |           0.252 |
# |          StdEpRet |          0.0759 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.1 |
# |             EpLen |            8.48 |
# |      AverageVVals |           0.579 |
# |          StdVVals |           0.254 |
# |          MaxVVals |            1.02 |
# |          MinVVals |           0.157 |
# | TotalEnvInteracts |         8.5e+04 |
# |            LossPi |       -1.75e-08 |
# |             LossV |          0.0079 |
# |       DeltaLossPi |         -0.0157 |
# |        DeltaLossV |        -0.00026 |
# |           Entropy |           0.628 |
# |                KL |         0.00571 |
# |          ClipFrac |           0.047 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |           0.212 |
# |      StdVal_EpRet |          0.0931 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |         -0.0518 |
# |  AverageVal_EpLen |             8.4 |
# |      StdVal_EpLen |           0.917 |
# |      MaxVal_EpLen |              11 |
# |      MinVal_EpLen |               8 |
# |              Time |            35.3 |
# ---------------------------------------

# %% [markdown]
# ## Visualize learning curves

# %%
dfs = [pd.read_csv(f'./outputs/grid_qbe_oracle_revealed/seed={seed}/progress.txt', sep='\t') for seed in range(10)]

# %% [markdown]
# ### All runs

# %%
for df in dfs:
    plt.plot(df['AverageVal_EpLen'])
    plt.fill_between(df['Epoch'], df['MinVal_EpLen'], df['MaxVal_EpLen'], alpha=0.1)
plt.xlabel('epoch')
plt.ylabel('Val EpLen')
plt.show()

# %%
for df in dfs:
    plt.plot(df['AverageVal_EpRet'])
    plt.fill_between(df['Epoch'], df['MinVal_EpRet'], df['MaxVal_EpRet'], alpha=0.1)
plt.xlabel('epoch')
plt.ylabel('Val EpRet')
plt.show()

# %% [markdown]
# ### Averaged

# %%
df_ = pd.concat(dfs).groupby('Epoch').mean().reset_index()

# %%
plt.plot(df_['AverageVal_EpLen'], color='k')
plt.fill_between(df_['Epoch'], df_['MinVal_EpLen'], df_['MaxVal_EpLen'], alpha=0.2, color='k')
plt.xlabel('epoch')
plt.ylabel('Val EpLen')
plt.show()

# %%
plt.plot(df_['AverageVal_EpRet'], color='k')
plt.fill_between(df_['Epoch'], df_['MinVal_EpRet'], df_['MaxVal_EpRet'], alpha=0.2, color='k')
plt.xlabel('epoch')
plt.ylabel('Val EpRet')
plt.show()
