# %%
import gym
import numpy as np
from offsim4rl.envs import gridworld
from offsim4rl.agents import spinup
import torch
# Out:
# No protocol specified

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from offsim4rl.data import OfflineDataset, ProbDistribution
from offsim4rl.evaluators.per_state_rejection import PerStateRejectionSampling

# %%
# the oracle observation-to-state mapping for the continuous gridworld
class OracleEncoder(object):
    def __init__(self):
        pass
    def encode(self, observations):
        zs = []
        for x, y in observations:
            xx, yy = int(x*5), int(y*5)
            z = xx + 5*yy
            zs.append(z)
        return zs

# %%
from offsim4rl.utils.dataset_utils import load_h5_dataset
buffer = load_h5_dataset('../outputs/MyGridNaviCoords-v1_random.h5')
# Out:
# load datafile: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 33.27it/s]

# %%
dataset = OfflineDataset(
    observation_space=gym.spaces.Box(low=0, high=1, shape=(2,)),
    action_space=gym.spaces.Discrete(5),
    action_dist_type=ProbDistribution.Discrete,
    observations=buffer['observations'],
    actions=buffer['actions'].astype(int),
    action_distributions=buffer['infos/probs'],
    rewards=buffer['rewards'],
    next_observations=buffer['next_observations'],
    terminals=buffer['terminals'].astype(bool),
    steps=buffer['infos/steps'].astype(int),
)
# Out:
# WARNING:root:Missing episode_ids in experience. Some algorithms may not be compatible with this dataset.

# %%
psrs = PerStateRejectionSampling(
    dataset,
    num_states=25,
    encoder=OracleEncoder(),
)

# %% [markdown]
# ## Learn

# %%
# true env for online validation
env = gym.make('MyGridNaviCoords-v1', seed=100000)
env.reset_task(np.array([4, 4]))
# Out:
# array([4, 4])

# %%
for seed in range(10):
    psrs.reset_sampler(seed=seed)
    spinup.ppo_revealed(
        env_fn=lambda: psrs, steps_per_epoch=5000, epochs=50, seed=seed, 
        logger_kwargs=dict(output_dir=f'./outputs/grid_psrs_oracle/seed={seed}', exp_name='MyGridNaviCoords-v1_ppo'), 
        ac_kwargs=dict(hidden_sizes=[32, 32], activation=torch.nn.ReLU), 
        validate=True, val_kwargs=dict(val_env_fn=lambda: env, val_n_episodes=10))
# Out:
# Warning: Log dir ./outputs/grid_psrs_oracle/seed=0 already exists! Storing info there anyway.
# Logging data to ./outputs/grid_psrs_oracle/seed=0/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             32,
#             32
#         ]
#     },
#     "actor_critic":	"MLPActorCritic",
#     "clip_ratio":	0.2,
#     "env_fn":	"<function <lambda> at 0x7f97dc2975f0>",
#     "epochs":	50,
#     "exp_name":	"MyGridNaviCoords-v1_ppo",
#     "gamma":	0.99,
#     "lam":	0.97,
#     "logger":	{
#         "<offsim4rl.agents.spinup.utils.logx.EpochLogger object at 0x7f97239e7fd0>":	{
#             "epoch_dict":	{},
#             "exp_name":	"MyGridNaviCoords-v1_ppo",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"./outputs/grid_psrs_oracle/seed=0",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='./outputs/grid_psrs_oracle/seed=0/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"MyGridNaviCoords-v1_ppo",
#         "output_dir":	"./outputs/grid_psrs_oracle/seed=0"
#     },
#     "max_ep_len":	1000,
#     "pi_lr":	0.0003,
#     "save_freq":	10,
#     "seed":	0,
#     "steps_per_epoch":	5000,
#     "target_kl":	0.01,
#     "train_pi_iters":	80,
#     "train_v_iters":	80,
#     "val_kwargs":	{
#         "val_env_fn":	"<function <lambda> at 0x7f9723889320>",
#         "val_n_episodes":	10
#     },
#     "validate":	true,
#     "vf_lr":	0.001
# }
#
# Number of parameters: 	 pi: 1317, 	 v: 1185
#
# Warning: trajectory cut off by epoch at 452 steps.
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |               0 |
# |      AverageEpRet |           -14.6 |
# |          StdEpRet |            12.8 |
# |          MaxEpRet |            -0.4 |
# |          MinEpRet |           -57.7 |
# |             EpLen |             157 |
# |      AverageVVals |          0.0173 |
# |          StdVVals |          0.0343 |
# |          MaxVVals |          0.0884 |
# |          MinVVals |         -0.0467 |
# | TotalEnvInteracts |           5e+03 |
# |            LossPi |       -1.27e-07 |
# |             LossV |            41.8 |
# |       DeltaLossPi |         -0.0182 |
# |        DeltaLossV |             -27 |
# |           Entropy |             1.6 |
# |                KL |          0.0118 |
# |          ClipFrac |           0.109 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |           -2.94 |
# |      StdVal_EpRet |            1.82 |
# |      MaxVal_EpRet |          -0.444 |
# |      MinVal_EpRet |           -6.99 |
# |  AverageVal_EpLen |            49.4 |
# |      StdVal_EpLen |            31.5 |
# |      MaxVal_EpLen |             130 |
# |      MinVal_EpLen |              15 |
# |              Time |            3.18 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 4 steps.
# Early stopping at step 60 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |           -5.94 |
# |          StdEpRet |            4.81 |
# |          MaxEpRet |            -0.1 |
# |          MinEpRet |           -23.9 |
# |             EpLen |            70.4 |
# |      AverageVVals |           -3.86 |
# |          StdVVals |           0.581 |
# |          MaxVVals |           -2.74 |
# |          MinVVals |           -4.82 |
# | TotalEnvInteracts |           1e+04 |
# |            LossPi |       -1.71e-08 |
# |             LossV |            8.49 |
# |       DeltaLossPi |         -0.0233 |
# |        DeltaLossV |           -1.78 |
# |           Entropy |            1.59 |
# |                KL |          0.0153 |
# |          ClipFrac |            0.17 |
# |          StopIter |              60 |
# |  AverageVal_EpRet |           -2.84 |
# |      StdVal_EpRet |            2.03 |
# |      MaxVal_EpRet |          -0.444 |
# |      MinVal_EpRet |            -5.5 |
# |  AverageVal_EpLen |            48.1 |
# |      StdVal_EpLen |            30.4 |
# |      MaxVal_EpLen |              90 |
# |      MinVal_EpLen |              15 |
# |              Time |            5.98 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 9 steps.
# Early stopping at step 30 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |           -2.27 |
# |          StdEpRet |            1.91 |
# |          MaxEpRet |             0.1 |
# |          MinEpRet |            -9.3 |
# |             EpLen |            33.7 |
# |      AverageVVals |           -2.65 |
# |          StdVVals |           0.273 |
# |          MaxVVals |           -2.14 |
# |          MinVVals |            -3.3 |
# | TotalEnvInteracts |         1.5e+04 |
# |            LossPi |        3.99e-08 |
# |             LossV |            5.03 |
# |       DeltaLossPi |         -0.0271 |
# |        DeltaLossV |           -2.81 |
# |           Entropy |            1.55 |
# |                KL |          0.0156 |
# |          ClipFrac |           0.358 |
# |          StopIter |              30 |
# |  AverageVal_EpRet |          -0.856 |
# |      StdVal_EpRet |           0.808 |
# |      MaxVal_EpRet |            0.15 |
# |      MinVal_EpRet |           -2.57 |
# |  AverageVal_EpLen |            19.8 |
# |      StdVal_EpLen |            9.21 |
# |      MaxVal_EpLen |              40 |
# |      MinVal_EpLen |               9 |
# |              Time |            8.65 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 10 steps.
# Early stopping at step 22 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |           -1.31 |
# |          StdEpRet |            1.14 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -6.2 |
# |             EpLen |            24.1 |
# |      AverageVVals |           -1.21 |
# |          StdVVals |           0.133 |
# |          MaxVVals |          -0.955 |
# |          MinVVals |           -1.58 |
# | TotalEnvInteracts |           2e+04 |
# |            LossPi |        2.16e-08 |
# |             LossV |            1.69 |
# |       DeltaLossPi |         -0.0281 |
# |        DeltaLossV |           -0.64 |
# |           Entropy |            1.48 |
# |                KL |          0.0158 |
# |          ClipFrac |           0.206 |
# |          StopIter |              22 |
# |  AverageVal_EpRet |          -0.917 |
# |      StdVal_EpRet |           0.978 |
# |      MaxVal_EpRet |            0.15 |
# |      MinVal_EpRet |           -3.34 |
# |  AverageVal_EpLen |            20.7 |
# |      StdVal_EpLen |            11.7 |
# |      MaxVal_EpLen |              51 |
# |      MinVal_EpLen |               9 |
# |              Time |            11.4 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 1 steps.
# Early stopping at step 20 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |          -0.698 |
# |          StdEpRet |           0.767 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -5.3 |
# |             EpLen |              18 |
# |      AverageVVals |          -0.616 |
# |          StdVVals |           0.124 |
# |          MaxVVals |          -0.426 |
# |          MinVVals |          -0.866 |
# | TotalEnvInteracts |         2.5e+04 |
# |            LossPi |         2.7e-08 |
# |             LossV |           0.867 |
# |       DeltaLossPi |         -0.0267 |
# |        DeltaLossV |          -0.317 |
# |           Entropy |            1.39 |
# |                KL |          0.0158 |
# |          ClipFrac |           0.281 |
# |          StopIter |              20 |
# |  AverageVal_EpRet |          -0.594 |
# |      StdVal_EpRet |           0.465 |
# |      MaxVal_EpRet |          -0.151 |
# |      MinVal_EpRet |           -1.53 |
# |  AverageVal_EpLen |            16.7 |
# |      StdVal_EpLen |            5.02 |
# |      MaxVal_EpLen |              27 |
# |      MinVal_EpLen |              12 |
# |              Time |            14.2 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 2 steps.
# Early stopping at step 28 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |          -0.415 |
# |          StdEpRet |           0.507 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -2.3 |
# |             EpLen |            15.1 |
# |      AverageVVals |          -0.237 |
# |          StdVVals |           0.145 |
# |          MaxVVals |         -0.0741 |
# |          MinVVals |          -0.593 |
# | TotalEnvInteracts |           3e+04 |
# |            LossPi |        2.69e-08 |
# |             LossV |           0.429 |
# |       DeltaLossPi |          -0.023 |
# |        DeltaLossV |          -0.107 |
# |           Entropy |            1.28 |
# |                KL |          0.0155 |
# |          ClipFrac |           0.287 |
# |          StopIter |              28 |
# |  AverageVal_EpRet |          -0.316 |
# |      StdVal_EpRet |           0.469 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |           -1.09 |
# |  AverageVal_EpLen |            13.8 |
# |      StdVal_EpLen |            4.89 |
# |      MaxVal_EpLen |              22 |
# |      MinVal_EpLen |               8 |
# |              Time |            17.1 |
# ---------------------------------------
# Early stopping at step 28 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |          -0.212 |
# |          StdEpRet |           0.406 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -2.1 |
# |             EpLen |            13.1 |
# |      AverageVVals |         -0.0794 |
# |          StdVVals |           0.147 |
# |          MaxVVals |          0.0559 |
# |          MinVVals |          -0.449 |
# | TotalEnvInteracts |         3.5e+04 |
# |            LossPi |       -2.19e-08 |
# |             LossV |           0.314 |
# |       DeltaLossPi |         -0.0218 |
# |        DeltaLossV |         -0.0539 |
# |           Entropy |            1.17 |
# |                KL |          0.0151 |
# |          ClipFrac |           0.158 |
# |          StopIter |              28 |
# |  AverageVal_EpRet |         -0.0675 |
# |      StdVal_EpRet |           0.288 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.634 |
# |  AverageVal_EpLen |            11.2 |
# |      StdVal_EpLen |            2.93 |
# |      MaxVal_EpLen |              17 |
# |      MinVal_EpLen |               8 |
# |              Time |              20 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 7 steps.
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |          -0.106 |
# |          StdEpRet |            0.33 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -1.6 |
# |             EpLen |            12.1 |
# |      AverageVVals |          0.0181 |
# |          StdVVals |           0.131 |
# |          MaxVVals |           0.122 |
# |          MinVVals |          -0.347 |
# | TotalEnvInteracts |           4e+04 |
# |            LossPi |       -5.46e-08 |
# |             LossV |           0.257 |
# |       DeltaLossPi |         -0.0241 |
# |        DeltaLossV |         -0.0412 |
# |           Entropy |            1.07 |
# |                KL |          0.0101 |
# |          ClipFrac |           0.118 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |          0.0501 |
# |      StdVal_EpRet |           0.169 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |           -0.25 |
# |  AverageVal_EpLen |              10 |
# |      StdVal_EpLen |            1.67 |
# |      MaxVal_EpLen |              13 |
# |      MinVal_EpLen |               8 |
# |              Time |            23.2 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 4 steps.
# Early stopping at step 28 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |         -0.0127 |
# |          StdEpRet |           0.264 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |              -1 |
# |             EpLen |            11.1 |
# |      AverageVVals |          0.0945 |
# |          StdVVals |           0.123 |
# |          MaxVVals |           0.194 |
# |          MinVVals |          -0.261 |
# | TotalEnvInteracts |         4.5e+04 |
# |            LossPi |        -5.3e-08 |
# |             LossV |           0.212 |
# |       DeltaLossPi |         -0.0158 |
# |        DeltaLossV |          -0.134 |
# |           Entropy |               1 |
# |                KL |          0.0158 |
# |          ClipFrac |           0.177 |
# |          StopIter |              28 |
# |  AverageVal_EpRet |          0.0803 |
# |      StdVal_EpRet |           0.157 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.151 |
# |  AverageVal_EpLen |             9.7 |
# |      StdVal_EpLen |            1.55 |
# |      MaxVal_EpLen |              12 |
# |      MinVal_EpLen |               8 |
# |              Time |            26.3 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 1 steps.
# Early stopping at step 17 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |          0.0386 |
# |          StdEpRet |           0.253 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -1.4 |
# |             EpLen |            10.6 |
# |      AverageVVals |           0.444 |
# |          StdVVals |           0.195 |
# |          MaxVVals |            0.71 |
# |          MinVVals |         -0.0678 |
# | TotalEnvInteracts |           5e+04 |
# |            LossPi |       -1.44e-08 |
# |             LossV |          0.0691 |
# |       DeltaLossPi |         -0.0275 |
# |        DeltaLossV |        -0.00891 |
# |           Entropy |           0.922 |
# |                KL |          0.0154 |
# |          ClipFrac |           0.422 |
# |          StopIter |              17 |
# |  AverageVal_EpRet |         0.00115 |
# |      StdVal_EpRet |           0.236 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.539 |
# |  AverageVal_EpLen |            10.5 |
# |      StdVal_EpLen |            2.38 |
# |      MaxVal_EpLen |              16 |
# |      MinVal_EpLen |               8 |
# |              Time |            29.4 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 3 steps.
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |           0.048 |
# |          StdEpRet |           0.242 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -1.2 |
# |             EpLen |            10.5 |
# |      AverageVVals |           0.478 |
# |          StdVVals |           0.252 |
# |          MaxVVals |           0.808 |
# |          MinVVals |          -0.136 |
# | TotalEnvInteracts |         5.5e+04 |
# |            LossPi |        5.72e-10 |
# |             LossV |          0.0623 |
# |       DeltaLossPi |         -0.0255 |
# |        DeltaLossV |        -0.00325 |
# |           Entropy |           0.893 |
# |                KL |         0.00923 |
# |          ClipFrac |           0.105 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |           0.131 |
# |      StdVal_EpRet |           0.118 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.151 |
# |  AverageVal_EpLen |             9.2 |
# |      StdVal_EpLen |            1.17 |
# |      MaxVal_EpLen |              12 |
# |      MinVal_EpLen |               8 |
# |              Time |            32.9 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 6 steps.
# Early stopping at step 20 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |           0.111 |
# |          StdEpRet |           0.202 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |              -1 |
# |             EpLen |            9.89 |
# |      AverageVVals |           0.451 |
# |          StdVVals |           0.268 |
# |          MaxVVals |           0.816 |
# |          MinVVals |          -0.178 |
# | TotalEnvInteracts |           6e+04 |
# |            LossPi |       -2.19e-09 |
# |             LossV |          0.0447 |
# |       DeltaLossPi |         -0.0178 |
# |        DeltaLossV |        -0.00329 |
# |           Entropy |           0.843 |
# |                KL |           0.016 |
# |          ClipFrac |           0.288 |
# |          StopIter |              20 |
# |  AverageVal_EpRet |          0.0198 |
# |      StdVal_EpRet |           0.167 |
# |      MaxVal_EpRet |            0.15 |
# |      MinVal_EpRet |          -0.347 |
# |  AverageVal_EpLen |            10.3 |
# |      StdVal_EpLen |            1.68 |
# |      MaxVal_EpLen |              14 |
# |      MinVal_EpLen |               9 |
# |              Time |              36 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 9 steps.
# Early stopping at step 13 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |           0.104 |
# |          StdEpRet |           0.214 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |              -1 |
# |             EpLen |            9.96 |
# |      AverageVVals |           0.515 |
# |          StdVVals |           0.287 |
# |          MaxVVals |            0.89 |
# |          MinVVals |          -0.149 |
# | TotalEnvInteracts |         6.5e+04 |
# |            LossPi |        3.05e-09 |
# |             LossV |          0.0499 |
# |       DeltaLossPi |         -0.0327 |
# |        DeltaLossV |        -0.00289 |
# |           Entropy |           0.824 |
# |                KL |          0.0186 |
# |          ClipFrac |           0.211 |
# |          StopIter |              13 |
# |  AverageVal_EpRet |          0.0289 |
# |      StdVal_EpRet |           0.088 |
# |      MaxVal_EpRet |            0.15 |
# |      MinVal_EpRet |         -0.0518 |
# |  AverageVal_EpLen |            10.2 |
# |      StdVal_EpLen |           0.872 |
# |      MaxVal_EpLen |              11 |
# |      MinVal_EpLen |               9 |
# |              Time |            39.1 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 7 steps.
# Early stopping at step 26 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |           0.138 |
# |          StdEpRet |           0.174 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.8 |
# |             EpLen |            9.62 |
# |      AverageVVals |           0.487 |
# |          StdVVals |           0.273 |
# |          MaxVVals |           0.855 |
# |          MinVVals |          -0.152 |
# | TotalEnvInteracts |           7e+04 |
# |            LossPi |       -1.34e-08 |
# |             LossV |          0.0331 |
# |       DeltaLossPi |         -0.0224 |
# |        DeltaLossV |        -0.00177 |
# |           Entropy |           0.798 |
# |                KL |          0.0167 |
# |          ClipFrac |           0.132 |
# |          StopIter |              26 |
# |  AverageVal_EpRet |           0.131 |
# |      StdVal_EpRet |           0.134 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.151 |
# |  AverageVal_EpLen |             9.2 |
# |      StdVal_EpLen |            1.33 |
# |      MaxVal_EpLen |              12 |
# |      MinVal_EpLen |               8 |
# |              Time |            42.3 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 8 steps.
# Early stopping at step 18 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |           0.136 |
# |          StdEpRet |           0.193 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.9 |
# |             EpLen |            9.64 |
# |      AverageVVals |           0.531 |
# |          StdVVals |           0.281 |
# |          MaxVVals |           0.908 |
# |          MinVVals |          -0.112 |
# | TotalEnvInteracts |         7.5e+04 |
# |            LossPi |       -5.53e-09 |
# |             LossV |          0.0413 |
# |       DeltaLossPi |         -0.0265 |
# |        DeltaLossV |        -0.00121 |
# |           Entropy |           0.768 |
# |                KL |          0.0173 |
# |          ClipFrac |           0.268 |
# |          StopIter |              18 |
# |  AverageVal_EpRet |           0.131 |
# |      StdVal_EpRet |           0.134 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.151 |
# |  AverageVal_EpLen |             9.2 |
# |      StdVal_EpLen |            1.33 |
# |      MaxVal_EpLen |              12 |
# |      MinVal_EpLen |               8 |
# |              Time |            45.6 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 3 steps.
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |           0.166 |
# |          StdEpRet |           0.151 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.4 |
# |             EpLen |            9.34 |
# |      AverageVVals |           0.508 |
# |          StdVVals |            0.27 |
# |          MaxVVals |           0.876 |
# |          MinVVals |         -0.0974 |
# | TotalEnvInteracts |           8e+04 |
# |            LossPi |       -7.44e-09 |
# |             LossV |          0.0263 |
# |       DeltaLossPi |         -0.0215 |
# |        DeltaLossV |        -0.00156 |
# |           Entropy |           0.751 |
# |                KL |         0.00758 |
# |          ClipFrac |          0.0808 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |          0.0795 |
# |      StdVal_EpRet |           0.102 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |         -0.0518 |
# |  AverageVal_EpLen |             9.7 |
# |      StdVal_EpLen |               1 |
# |      MaxVal_EpLen |              11 |
# |      MinVal_EpLen |               8 |
# |              Time |            48.9 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 2 steps.
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |           0.199 |
# |          StdEpRet |           0.139 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.6 |
# |             EpLen |            9.01 |
# |      AverageVVals |           0.536 |
# |          StdVVals |           0.274 |
# |          MaxVVals |           0.922 |
# |          MinVVals |         -0.0683 |
# | TotalEnvInteracts |         8.5e+04 |
# |            LossPi |        1.18e-08 |
# |             LossV |          0.0229 |
# |       DeltaLossPi |         -0.0208 |
# |        DeltaLossV |       -0.000914 |
# |           Entropy |           0.723 |
# |                KL |         0.00436 |
# |          ClipFrac |          0.0454 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |           0.191 |
# |      StdVal_EpRet |          0.0678 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          0.0487 |
# |  AverageVal_EpLen |             8.6 |
# |      StdVal_EpLen |           0.663 |
# |      MaxVal_EpLen |              10 |
# |      MinVal_EpLen |               8 |
# |              Time |            52.3 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 1 steps.
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |           0.214 |
# |          StdEpRet |           0.117 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.5 |
# |             EpLen |            8.86 |
# |      AverageVVals |           0.556 |
# |          StdVVals |           0.266 |
# |          MaxVVals |            0.94 |
# |          MinVVals |         -0.0243 |
# | TotalEnvInteracts |           9e+04 |
# |            LossPi |       -1.53e-08 |
# |             LossV |          0.0177 |
# |       DeltaLossPi |         -0.0214 |
# |        DeltaLossV |       -0.000485 |
# |           Entropy |            0.69 |
# |                KL |         0.00709 |
# |          ClipFrac |          0.0752 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |           0.131 |
# |      StdVal_EpRet |           0.148 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |           -0.25 |
# |  AverageVal_EpLen |             9.2 |
# |      StdVal_EpLen |            1.47 |
# |      MaxVal_EpLen |              13 |
# |      MinVal_EpLen |               8 |
# |              Time |            55.8 |
# ---------------------------------------
# Logging data to ./outputs/grid_psrs_oracle/seed=1/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             32,
#             32
#         ]
#     },
#     "actor_critic":	"MLPActorCritic",
#     "clip_ratio":	0.2,
#     "env_fn":	"<function <lambda> at 0x7f97dc2975f0>",
#     "epochs":	50,
#     "exp_name":	"MyGridNaviCoords-v1_ppo",
#     "gamma":	0.99,
#     "lam":	0.97,
#     "logger":	{
#         "<offsim4rl.agents.spinup.utils.logx.EpochLogger object at 0x7f96df64df10>":	{
#             "epoch_dict":	{},
#             "exp_name":	"MyGridNaviCoords-v1_ppo",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"./outputs/grid_psrs_oracle/seed=1",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='./outputs/grid_psrs_oracle/seed=1/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"MyGridNaviCoords-v1_ppo",
#         "output_dir":	"./outputs/grid_psrs_oracle/seed=1"
#     },
#     "max_ep_len":	1000,
#     "pi_lr":	0.0003,
#     "save_freq":	10,
#     "seed":	1,
#     "steps_per_epoch":	5000,
#     "target_kl":	0.01,
#     "train_pi_iters":	80,
#     "train_v_iters":	80,
#     "val_kwargs":	{
#         "val_env_fn":	"<function <lambda> at 0x7f96df653f80>",
#         "val_n_episodes":	10
#     },
#     "validate":	true,
#     "vf_lr":	0.001
# }
#
# Number of parameters: 	 pi: 1317, 	 v: 1185
#
# Warning: trajectory cut off by epoch at 81 steps.
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |               0 |
# |      AverageEpRet |           -14.3 |
# |          StdEpRet |            11.2 |
# |          MaxEpRet |            -1.2 |
# |          MinEpRet |           -63.5 |
# |             EpLen |             154 |
# |      AverageVVals |         -0.0623 |
# |          StdVVals |          0.0419 |
# |          MaxVVals |          0.0187 |
# |          MinVVals |          -0.146 |
# | TotalEnvInteracts |           5e+03 |
# |            LossPi |       -2.06e-08 |
# |             LossV |            33.7 |
# |       DeltaLossPi |         -0.0192 |
# |        DeltaLossV |           -16.5 |
# |           Entropy |            1.61 |
# |                KL |          0.0116 |
# |          ClipFrac |          0.0856 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |           -3.89 |
# |      StdVal_EpRet |            2.47 |
# |      MaxVal_EpRet |           -0.25 |
# |      MinVal_EpRet |            -7.9 |
# |  AverageVal_EpLen |            69.3 |
# |      StdVal_EpLen |            46.8 |
# |      MaxVal_EpLen |             166 |
# |      MinVal_EpLen |              13 |
# |              Time |            2.88 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 67 steps.
# Early stopping at step 47 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |           -5.22 |
# |          StdEpRet |            3.84 |
# |          MaxEpRet |       -1.49e-08 |
# |          MinEpRet |           -15.3 |
# |             EpLen |            63.2 |
# |      AverageVVals |           -2.41 |
# |          StdVVals |           0.353 |
# |          MaxVVals |           -1.83 |
# |          MinVVals |           -3.29 |
# | TotalEnvInteracts |           1e+04 |
# |            LossPi |        1.05e-08 |
# |             LossV |            5.65 |
# |       DeltaLossPi |         -0.0224 |
# |        DeltaLossV |           -0.34 |
# |           Entropy |            1.59 |
# |                KL |          0.0153 |
# |          ClipFrac |           0.106 |
# |          StopIter |              47 |
# |  AverageVal_EpRet |           -2.39 |
# |      StdVal_EpRet |            1.64 |
# |      MaxVal_EpRet |          -0.634 |
# |      MinVal_EpRet |           -6.43 |
# |  AverageVal_EpLen |            40.8 |
# |      StdVal_EpLen |            26.9 |
# |      MaxVal_EpLen |             113 |
# |      MinVal_EpLen |              17 |
# |              Time |            5.55 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 15 steps.
# Early stopping at step 28 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |           -2.29 |
# |          StdEpRet |            1.68 |
# |          MaxEpRet |             0.1 |
# |          MinEpRet |              -9 |
# |             EpLen |            33.9 |
# |      AverageVVals |           -2.37 |
# |          StdVVals |           0.203 |
# |          MaxVVals |           -2.02 |
# |          MinVVals |           -2.79 |
# | TotalEnvInteracts |         1.5e+04 |
# |            LossPi |       -1.56e-08 |
# |             LossV |            4.22 |
# |       DeltaLossPi |         -0.0268 |
# |        DeltaLossV |           -2.33 |
# |           Entropy |            1.55 |
# |                KL |          0.0156 |
# |          ClipFrac |           0.181 |
# |          StopIter |              28 |
# |  AverageVal_EpRet |           -1.09 |
# |      StdVal_EpRet |           0.933 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |           -2.64 |
# |  AverageVal_EpLen |            22.5 |
# |      StdVal_EpLen |            10.7 |
# |      MaxVal_EpLen |              41 |
# |      MinVal_EpLen |               8 |
# |              Time |            8.34 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 1 steps.
# Early stopping at step 26 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -1.1 |
# |          StdEpRet |            1.08 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -5.6 |
# |             EpLen |              22 |
# |      AverageVVals |           -1.12 |
# |          StdVVals |           0.077 |
# |          MaxVVals |           -1.01 |
# |          MinVVals |           -1.26 |
# | TotalEnvInteracts |           2e+04 |
# |            LossPi |        1.93e-08 |
# |             LossV |            1.61 |
# |       DeltaLossPi |         -0.0276 |
# |        DeltaLossV |          -0.682 |
# |           Entropy |            1.48 |
# |                KL |          0.0154 |
# |          ClipFrac |           0.267 |
# |          StopIter |              26 |
# |  AverageVal_EpRet |          -0.659 |
# |      StdVal_EpRet |           0.733 |
# |      MaxVal_EpRet |          0.0487 |
# |      MinVal_EpRet |           -2.57 |
# |  AverageVal_EpLen |            17.6 |
# |      StdVal_EpLen |            8.38 |
# |      MaxVal_EpLen |              40 |
# |      MinVal_EpLen |              10 |
# |              Time |            11.1 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 9 steps.
# Early stopping at step 22 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |          -0.715 |
# |          StdEpRet |           0.738 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -3.8 |
# |             EpLen |            18.1 |
# |      AverageVVals |          -0.559 |
# |          StdVVals |           0.187 |
# |          MaxVVals |          -0.269 |
# |          MinVVals |          -0.911 |
# | TotalEnvInteracts |         2.5e+04 |
# |            LossPi |        1.32e-08 |
# |             LossV |           0.734 |
# |       DeltaLossPi |         -0.0269 |
# |        DeltaLossV |          -0.321 |
# |           Entropy |            1.37 |
# |                KL |          0.0154 |
# |          ClipFrac |           0.228 |
# |          StopIter |              22 |
# |  AverageVal_EpRet |          -0.351 |
# |      StdVal_EpRet |           0.332 |
# |      MaxVal_EpRet |            0.15 |
# |      MinVal_EpRet |           -1.09 |
# |  AverageVal_EpLen |            14.1 |
# |      StdVal_EpLen |            3.48 |
# |      MaxVal_EpLen |              22 |
# |      MinVal_EpLen |               9 |
# |              Time |            13.9 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 5 steps.
# Early stopping at step 23 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |          -0.361 |
# |          StdEpRet |           0.551 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |              -4 |
# |             EpLen |            14.6 |
# |      AverageVVals |         -0.0119 |
# |          StdVVals |           0.312 |
# |          MaxVVals |           0.399 |
# |          MinVVals |          -0.614 |
# | TotalEnvInteracts |           3e+04 |
# |            LossPi |       -8.39e-09 |
# |             LossV |           0.284 |
# |       DeltaLossPi |         -0.0277 |
# |        DeltaLossV |         -0.0463 |
# |           Entropy |            1.27 |
# |                KL |          0.0156 |
# |          ClipFrac |           0.204 |
# |          StopIter |              23 |
# |  AverageVal_EpRet |         -0.0746 |
# |      StdVal_EpRet |           0.371 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |              -1 |
# |  AverageVal_EpLen |            11.3 |
# |      StdVal_EpLen |            3.82 |
# |      MaxVal_EpLen |              21 |
# |      MinVal_EpLen |               8 |
# |              Time |            16.8 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 7 steps.
# Early stopping at step 33 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |          -0.204 |
# |          StdEpRet |             0.4 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -2.2 |
# |             EpLen |              13 |
# |      AverageVVals |           0.191 |
# |          StdVVals |           0.371 |
# |          MaxVVals |           0.721 |
# |          MinVVals |          -0.503 |
# | TotalEnvInteracts |         3.5e+04 |
# |            LossPi |        9.54e-09 |
# |             LossV |           0.133 |
# |       DeltaLossPi |         -0.0237 |
# |        DeltaLossV |         -0.0141 |
# |           Entropy |            1.15 |
# |                KL |          0.0152 |
# |          ClipFrac |           0.145 |
# |          StopIter |              33 |
# |  AverageVal_EpRet |          -0.024 |
# |      StdVal_EpRet |           0.384 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |           -1.09 |
# |  AverageVal_EpLen |            10.8 |
# |      StdVal_EpLen |            3.99 |
# |      MaxVal_EpLen |              22 |
# |      MinVal_EpLen |               8 |
# |              Time |            19.7 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 5 steps.
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |         -0.0836 |
# |          StdEpRet |            0.33 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |              -2 |
# |             EpLen |            11.8 |
# |      AverageVVals |           0.304 |
# |          StdVVals |           0.376 |
# |          MaxVVals |           0.856 |
# |          MinVVals |          -0.385 |
# | TotalEnvInteracts |           4e+04 |
# |            LossPi |        2.29e-09 |
# |             LossV |          0.0958 |
# |       DeltaLossPi |         -0.0246 |
# |        DeltaLossV |        -0.00827 |
# |           Entropy |            1.04 |
# |                KL |         0.00812 |
# |          ClipFrac |          0.0846 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |        0.000442 |
# |      StdVal_EpRet |           0.204 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.539 |
# |  AverageVal_EpLen |            10.5 |
# |      StdVal_EpLen |            2.06 |
# |      MaxVal_EpLen |              16 |
# |      MinVal_EpLen |               8 |
# |              Time |              23 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 3 steps.
# Early stopping at step 18 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |         -0.0305 |
# |          StdEpRet |           0.302 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -1.5 |
# |             EpLen |            11.3 |
# |      AverageVVals |           0.381 |
# |          StdVVals |           0.353 |
# |          MaxVVals |           0.901 |
# |          MinVVals |          -0.256 |
# | TotalEnvInteracts |         4.5e+04 |
# |            LossPi |       -3.05e-09 |
# |             LossV |          0.0824 |
# |       DeltaLossPi |         -0.0302 |
# |        DeltaLossV |        -0.00445 |
# |           Entropy |           0.965 |
# |                KL |          0.0163 |
# |          ClipFrac |          0.0898 |
# |          StopIter |              18 |
# |  AverageVal_EpRet |            0.03 |
# |      StdVal_EpRet |           0.172 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.347 |
# |  AverageVal_EpLen |            10.2 |
# |      StdVal_EpLen |            1.72 |
# |      MaxVal_EpLen |              14 |
# |      MinVal_EpLen |               8 |
# |              Time |            26.4 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 2 steps.
# Early stopping at step 37 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |          0.0228 |
# |          StdEpRet |           0.244 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.9 |
# |             EpLen |            10.8 |
# |      AverageVVals |           0.402 |
# |          StdVVals |           0.328 |
# |          MaxVVals |           0.895 |
# |          MinVVals |          -0.172 |
# | TotalEnvInteracts |           5e+04 |
# |            LossPi |        1.22e-08 |
# |             LossV |          0.0563 |
# |       DeltaLossPi |         -0.0249 |
# |        DeltaLossV |        -0.00383 |
# |           Entropy |           0.925 |
# |                KL |          0.0155 |
# |          ClipFrac |            0.21 |
# |          StopIter |              37 |
# |  AverageVal_EpRet |           0.171 |
# |      StdVal_EpRet |          0.0996 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |         -0.0518 |
# |  AverageVal_EpLen |             8.8 |
# |      StdVal_EpLen |            0.98 |
# |      MaxVal_EpLen |              11 |
# |      MinVal_EpLen |               8 |
# |              Time |            29.5 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# Early stopping at step 22 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |          0.0496 |
# |          StdEpRet |           0.252 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -1.2 |
# |             EpLen |            10.5 |
# |      AverageVVals |           0.455 |
# |          StdVVals |           0.308 |
# |          MaxVVals |            0.93 |
# |          MinVVals |         -0.0814 |
# | TotalEnvInteracts |         5.5e+04 |
# |            LossPi |       -1.87e-08 |
# |             LossV |          0.0601 |
# |       DeltaLossPi |         -0.0285 |
# |        DeltaLossV |        -0.00233 |
# |           Entropy |           0.863 |
# |                KL |          0.0155 |
# |          ClipFrac |           0.175 |
# |          StopIter |              22 |
# |  AverageVal_EpRet |          -0.008 |
# |      StdVal_EpRet |            0.27 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.539 |
# |  AverageVal_EpLen |            10.6 |
# |      StdVal_EpLen |            2.73 |
# |      MaxVal_EpLen |              16 |
# |      MinVal_EpLen |               8 |
# |              Time |            32.9 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 2 steps.
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |          0.0821 |
# |          StdEpRet |           0.208 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |              -1 |
# |             EpLen |            10.2 |
# |      AverageVVals |           0.465 |
# |          StdVVals |           0.297 |
# |          MaxVVals |           0.927 |
# |          MinVVals |         -0.0403 |
# | TotalEnvInteracts |           6e+04 |
# |            LossPi |           1e-08 |
# |             LossV |          0.0429 |
# |       DeltaLossPi |         -0.0261 |
# |        DeltaLossV |        -0.00097 |
# |           Entropy |           0.842 |
# |                KL |         0.00982 |
# |          ClipFrac |           0.108 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |          0.0913 |
# |      StdVal_EpRet |           0.207 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |           -0.25 |
# |  AverageVal_EpLen |             9.6 |
# |      StdVal_EpLen |            2.06 |
# |      MaxVal_EpLen |              13 |
# |      MinVal_EpLen |               8 |
# |              Time |            36.2 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 2 steps.
# Early stopping at step 19 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |            0.11 |
# |          StdEpRet |           0.194 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.6 |
# |             EpLen |             9.9 |
# |      AverageVVals |            0.49 |
# |          StdVVals |           0.287 |
# |          MaxVVals |           0.943 |
# |          MinVVals |         0.00469 |
# | TotalEnvInteracts |         6.5e+04 |
# |            LossPi |        2.48e-09 |
# |             LossV |          0.0351 |
# |       DeltaLossPi |         -0.0215 |
# |        DeltaLossV |       -0.000549 |
# |           Entropy |           0.802 |
# |                KL |          0.0151 |
# |          ClipFrac |           0.174 |
# |          StopIter |              19 |
# |  AverageVal_EpRet |          0.0907 |
# |      StdVal_EpRet |           0.176 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |           -0.25 |
# |  AverageVal_EpLen |             9.6 |
# |      StdVal_EpLen |            1.74 |
# |      MaxVal_EpLen |              13 |
# |      MinVal_EpLen |               8 |
# |              Time |            39.3 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 11 steps.
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |           0.137 |
# |          StdEpRet |           0.171 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.7 |
# |             EpLen |            9.63 |
# |      AverageVVals |           0.498 |
# |          StdVVals |           0.279 |
# |          MaxVVals |           0.947 |
# |          MinVVals |          0.0363 |
# | TotalEnvInteracts |           7e+04 |
# |            LossPi |       -3.62e-09 |
# |             LossV |          0.0286 |
# |       DeltaLossPi |         -0.0273 |
# |        DeltaLossV |       -0.000955 |
# |           Entropy |           0.783 |
# |                KL |         0.00647 |
# |          ClipFrac |           0.109 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |          0.0509 |
# |      StdVal_EpRet |           0.207 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.539 |
# |  AverageVal_EpLen |              10 |
# |      StdVal_EpLen |             2.1 |
# |      MaxVal_EpLen |              16 |
# |      MinVal_EpLen |               8 |
# |              Time |            42.6 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 7 steps.
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |           0.163 |
# |          StdEpRet |           0.157 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.6 |
# |             EpLen |            9.37 |
# |      AverageVVals |            0.52 |
# |          StdVVals |           0.278 |
# |          MaxVVals |           0.975 |
# |          MinVVals |          0.0655 |
# | TotalEnvInteracts |         7.5e+04 |
# |            LossPi |         2.1e-09 |
# |             LossV |          0.0258 |
# |       DeltaLossPi |         -0.0234 |
# |        DeltaLossV |       -0.000474 |
# |           Entropy |           0.752 |
# |                KL |         0.00433 |
# |          ClipFrac |          0.0428 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |           0.151 |
# |      StdVal_EpRet |           0.149 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |           -0.25 |
# |  AverageVal_EpLen |               9 |
# |      StdVal_EpLen |            1.48 |
# |      MaxVal_EpLen |              13 |
# |      MinVal_EpLen |               8 |
# |              Time |              46 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 10 steps.
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |           0.194 |
# |          StdEpRet |           0.136 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.5 |
# |             EpLen |            9.06 |
# |      AverageVVals |           0.529 |
# |          StdVVals |           0.268 |
# |          MaxVVals |           0.977 |
# |          MinVVals |           0.103 |
# | TotalEnvInteracts |           8e+04 |
# |            LossPi |        1.03e-08 |
# |             LossV |          0.0205 |
# |       DeltaLossPi |         -0.0272 |
# |        DeltaLossV |       -0.000795 |
# |           Entropy |           0.718 |
# |                KL |         0.00765 |
# |          ClipFrac |            0.06 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |           0.161 |
# |      StdVal_EpRet |          0.0848 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          0.0487 |
# |  AverageVal_EpLen |             8.9 |
# |      StdVal_EpLen |           0.831 |
# |      MaxVal_EpLen |              10 |
# |      MinVal_EpLen |               8 |
# |              Time |            49.4 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 6 steps.
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |           0.221 |
# |          StdEpRet |           0.111 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.4 |
# |             EpLen |            8.79 |
# |      AverageVVals |           0.555 |
# |          StdVVals |           0.262 |
# |          MaxVVals |               1 |
# |          MinVVals |           0.139 |
# | TotalEnvInteracts |         8.5e+04 |
# |            LossPi |         6.1e-09 |
# |             LossV |          0.0144 |
# |       DeltaLossPi |         -0.0195 |
# |        DeltaLossV |       -0.000421 |
# |           Entropy |           0.685 |
# |                KL |         0.00379 |
# |          ClipFrac |           0.046 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |           0.212 |
# |      StdVal_EpRet |           0.121 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.151 |
# |  AverageVal_EpLen |             8.4 |
# |      StdVal_EpLen |             1.2 |
# |      MaxVal_EpLen |              12 |
# |      MinVal_EpLen |               8 |
# |              Time |            52.9 |
# ...
# |           Entropy |            1.36 |
# |                KL |          0.0154 |
# |          ClipFrac |           0.237 |
# |          StopIter |              24 |
# |  AverageVal_EpRet |          -0.302 |
# |      StdVal_EpRet |           0.352 |
# |      MaxVal_EpRet |            0.15 |
# |      MinVal_EpRet |           -1.09 |
# |  AverageVal_EpLen |            13.6 |
# |      StdVal_EpLen |            3.67 |
# |      MaxVal_EpLen |              22 |
# |      MinVal_EpLen |               9 |
# |              Time |            12.9 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 9 steps.
# Early stopping at step 22 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |          -0.275 |
# |          StdEpRet |           0.414 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -2.1 |
# |             EpLen |            13.7 |
# |      AverageVVals |          0.0925 |
# |          StdVVals |           0.292 |
# |          MaxVVals |           0.549 |
# |          MinVVals |          -0.444 |
# | TotalEnvInteracts |           3e+04 |
# |            LossPi |       -7.63e-10 |
# |             LossV |           0.168 |
# |       DeltaLossPi |         -0.0283 |
# |        DeltaLossV |         -0.0347 |
# |           Entropy |            1.24 |
# |                KL |          0.0156 |
# |          ClipFrac |           0.181 |
# |          StopIter |              22 |
# |  AverageVal_EpRet |          -0.242 |
# |      StdVal_EpRet |           0.372 |
# |      MaxVal_EpRet |            0.15 |
# |      MinVal_EpRet |           -1.18 |
# |  AverageVal_EpLen |              13 |
# |      StdVal_EpLen |             3.9 |
# |      MaxVal_EpLen |              23 |
# |      MinVal_EpLen |               9 |
# |              Time |            15.7 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 5 steps.
# Early stopping at step 27 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |          -0.165 |
# |          StdEpRet |           0.346 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -1.9 |
# |             EpLen |            12.6 |
# |      AverageVVals |           0.267 |
# |          StdVVals |           0.344 |
# |          MaxVVals |           0.806 |
# |          MinVVals |          -0.368 |
# | TotalEnvInteracts |         3.5e+04 |
# |            LossPi |       -8.77e-09 |
# |             LossV |          0.0988 |
# |       DeltaLossPi |         -0.0286 |
# |        DeltaLossV |        -0.00532 |
# |           Entropy |            1.13 |
# |                KL |          0.0159 |
# |          ClipFrac |            0.27 |
# |          StopIter |              27 |
# |  AverageVal_EpRet |         -0.0101 |
# |      StdVal_EpRet |            0.18 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.347 |
# |  AverageVal_EpLen |            10.6 |
# |      StdVal_EpLen |             1.8 |
# |      MaxVal_EpLen |              14 |
# |      MinVal_EpLen |               8 |
# |              Time |            18.5 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 8 steps.
# Early stopping at step 21 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |         -0.0168 |
# |          StdEpRet |           0.276 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -1.3 |
# |             EpLen |            11.2 |
# |      AverageVVals |           0.327 |
# |          StdVVals |           0.355 |
# |          MaxVVals |           0.895 |
# |          MinVVals |          -0.329 |
# | TotalEnvInteracts |           4e+04 |
# |            LossPi |       -1.28e-08 |
# |             LossV |          0.0735 |
# |       DeltaLossPi |         -0.0283 |
# |        DeltaLossV |         -0.0105 |
# |           Entropy |            1.03 |
# |                KL |          0.0162 |
# |          ClipFrac |           0.202 |
# |          StopIter |              21 |
# |  AverageVal_EpRet |         -0.0301 |
# |      StdVal_EpRet |           0.183 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.347 |
# |  AverageVal_EpLen |            10.8 |
# |      StdVal_EpLen |            1.83 |
# |      MaxVal_EpLen |              14 |
# |      MinVal_EpLen |               8 |
# |              Time |            21.4 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 12 steps.
# Early stopping at step 21 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |          0.0342 |
# |          StdEpRet |           0.252 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -1.2 |
# |             EpLen |            10.7 |
# |      AverageVVals |           0.431 |
# |          StdVVals |           0.342 |
# |          MaxVVals |           0.961 |
# |          MinVVals |          -0.217 |
# | TotalEnvInteracts |         4.5e+04 |
# |            LossPi |        3.81e-09 |
# |             LossV |          0.0598 |
# |       DeltaLossPi |         -0.0314 |
# |        DeltaLossV |        -0.00482 |
# |           Entropy |            0.96 |
# |                KL |          0.0156 |
# |          ClipFrac |           0.433 |
# |          StopIter |              21 |
# |  AverageVal_EpRet |         -0.0975 |
# |      StdVal_EpRet |           0.286 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.728 |
# |  AverageVal_EpLen |            11.5 |
# |      StdVal_EpLen |            2.91 |
# |      MaxVal_EpLen |              18 |
# |      MinVal_EpLen |               8 |
# |              Time |            24.3 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 7 steps.
# Early stopping at step 23 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |          0.0377 |
# |          StdEpRet |           0.255 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -1.5 |
# |             EpLen |            10.6 |
# |      AverageVVals |            0.45 |
# |          StdVVals |           0.322 |
# |          MaxVVals |            0.95 |
# |          MinVVals |           -0.12 |
# | TotalEnvInteracts |           5e+04 |
# |            LossPi |        4.01e-09 |
# |             LossV |           0.059 |
# |       DeltaLossPi |          -0.029 |
# |        DeltaLossV |        -0.00145 |
# |           Entropy |           0.905 |
# |                KL |          0.0163 |
# |          ClipFrac |           0.322 |
# |          StopIter |              23 |
# |  AverageVal_EpRet |           0.111 |
# |      StdVal_EpRet |           0.145 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.151 |
# |  AverageVal_EpLen |             9.4 |
# |      StdVal_EpLen |            1.43 |
# |      MaxVal_EpLen |              12 |
# |      MinVal_EpLen |               8 |
# |              Time |            27.2 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 1 steps.
# Warning: could not pickle state_dict.
# Early stopping at step 25 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |          0.0881 |
# |          StdEpRet |           0.203 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.7 |
# |             EpLen |            10.1 |
# |      AverageVVals |           0.455 |
# |          StdVVals |            0.29 |
# |          MaxVVals |           0.928 |
# |          MinVVals |         -0.0494 |
# | TotalEnvInteracts |         5.5e+04 |
# |            LossPi |       -1.04e-08 |
# |             LossV |          0.0381 |
# |       DeltaLossPi |         -0.0266 |
# |        DeltaLossV |        -0.00168 |
# |           Entropy |           0.858 |
# |                KL |          0.0155 |
# |          ClipFrac |           0.351 |
# |          StopIter |              25 |
# |  AverageVal_EpRet |           0.161 |
# |      StdVal_EpRet |           0.116 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |         -0.0518 |
# |  AverageVal_EpLen |             8.9 |
# |      StdVal_EpLen |            1.14 |
# |      MaxVal_EpLen |              11 |
# |      MinVal_EpLen |               8 |
# |              Time |            30.5 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 3 steps.
# Early stopping at step 14 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |            0.12 |
# |          StdEpRet |           0.199 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |              -1 |
# |             EpLen |             9.8 |
# |      AverageVVals |           0.488 |
# |          StdVVals |           0.286 |
# |          MaxVVals |           0.967 |
# |          MinVVals |       -0.000579 |
# | TotalEnvInteracts |           6e+04 |
# |            LossPi |       -4.77e-10 |
# |             LossV |          0.0369 |
# |       DeltaLossPi |         -0.0339 |
# |        DeltaLossV |        -0.00181 |
# |           Entropy |           0.821 |
# |                KL |          0.0163 |
# |          ClipFrac |            0.18 |
# |          StopIter |              14 |
# |  AverageVal_EpRet |           0.121 |
# |      StdVal_EpRet |           0.156 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |           -0.25 |
# |  AverageVal_EpLen |             9.3 |
# |      StdVal_EpLen |            1.55 |
# |      MaxVal_EpLen |              13 |
# |      MinVal_EpLen |               8 |
# |              Time |            33.5 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 1 steps.
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |           0.131 |
# |          StdEpRet |            0.18 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.7 |
# |             EpLen |            9.69 |
# |      AverageVVals |           0.517 |
# |          StdVVals |           0.277 |
# |          MaxVVals |           0.977 |
# |          MinVVals |          0.0352 |
# | TotalEnvInteracts |         6.5e+04 |
# |            LossPi |        6.48e-09 |
# |             LossV |          0.0306 |
# |       DeltaLossPi |         -0.0275 |
# |        DeltaLossV |       -0.000998 |
# |           Entropy |             0.8 |
# |                KL |         0.00622 |
# |          ClipFrac |          0.0684 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |          0.0906 |
# |      StdVal_EpRet |            0.17 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |           -0.25 |
# |  AverageVal_EpLen |             9.6 |
# |      StdVal_EpLen |            1.69 |
# |      MaxVal_EpLen |              13 |
# |      MinVal_EpLen |               8 |
# |              Time |            36.6 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 10 steps.
# Early stopping at step 20 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |           0.172 |
# |          StdEpRet |           0.155 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.6 |
# |             EpLen |            9.28 |
# |      AverageVVals |            0.51 |
# |          StdVVals |           0.274 |
# |          MaxVVals |           0.972 |
# |          MinVVals |          0.0402 |
# | TotalEnvInteracts |           7e+04 |
# |            LossPi |        1.43e-09 |
# |             LossV |          0.0246 |
# |       DeltaLossPi |         -0.0147 |
# |        DeltaLossV |        -0.00119 |
# |           Entropy |           0.762 |
# |                KL |          0.0151 |
# |          ClipFrac |           0.137 |
# |          StopIter |              20 |
# |  AverageVal_EpRet |           0.131 |
# |      StdVal_EpRet |           0.134 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |          -0.151 |
# |  AverageVal_EpLen |             9.2 |
# |      StdVal_EpLen |            1.33 |
# |      MaxVal_EpLen |              12 |
# |      MinVal_EpLen |               8 |
# |              Time |            39.6 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 4 steps.
# Early stopping at step 12 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |           0.177 |
# |          StdEpRet |           0.161 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.9 |
# |             EpLen |            9.23 |
# |      AverageVVals |           0.545 |
# |          StdVVals |           0.266 |
# |          MaxVVals |               1 |
# |          MinVVals |           0.085 |
# | TotalEnvInteracts |         7.5e+04 |
# |            LossPi |       -4.01e-09 |
# |             LossV |          0.0273 |
# |       DeltaLossPi |         -0.0319 |
# |        DeltaLossV |       -0.000338 |
# |           Entropy |           0.747 |
# |                KL |          0.0172 |
# |          ClipFrac |             0.3 |
# |          StopIter |              12 |
# |  AverageVal_EpRet |           0.151 |
# |      StdVal_EpRet |           0.102 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |         -0.0518 |
# |  AverageVal_EpLen |               9 |
# |      StdVal_EpLen |               1 |
# |      MaxVal_EpLen |              11 |
# |      MinVal_EpLen |               8 |
# |              Time |            42.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |           0.188 |
# |          StdEpRet |           0.138 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.4 |
# |             EpLen |            9.12 |
# |      AverageVVals |           0.544 |
# |          StdVVals |           0.262 |
# |          MaxVVals |           0.998 |
# |          MinVVals |          0.0841 |
# | TotalEnvInteracts |           8e+04 |
# |            LossPi |        1.91e-09 |
# |             LossV |          0.0222 |
# |       DeltaLossPi |         -0.0241 |
# |        DeltaLossV |       -0.000541 |
# |           Entropy |           0.737 |
# |                KL |         0.00663 |
# |          ClipFrac |           0.072 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |           0.181 |
# |      StdVal_EpRet |           0.102 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |         -0.0518 |
# |  AverageVal_EpLen |             8.7 |
# |      StdVal_EpLen |               1 |
# |      MaxVal_EpLen |              11 |
# |      MinVal_EpLen |               8 |
# |              Time |            45.9 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 5 steps.
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |           0.217 |
# |          StdEpRet |            0.11 |
# |          MaxEpRet |             0.3 |
# |          MinEpRet |            -0.3 |
# |             EpLen |            8.83 |
# |      AverageVVals |           0.549 |
# |          StdVVals |           0.262 |
# |          MaxVVals |            1.01 |
# |          MinVVals |           0.108 |
# | TotalEnvInteracts |         8.5e+04 |
# |            LossPi |        1.49e-08 |
# |             LossV |           0.014 |
# |       DeltaLossPi |         -0.0236 |
# |        DeltaLossV |       -0.000625 |
# |           Entropy |           0.707 |
# |                KL |          0.0067 |
# |          ClipFrac |          0.0618 |
# |          StopIter |              79 |
# |  AverageVal_EpRet |           0.222 |
# |      StdVal_EpRet |           0.047 |
# |      MaxVal_EpRet |           0.253 |
# |      MinVal_EpRet |            0.15 |
# |  AverageVal_EpLen |             8.3 |
# |      StdVal_EpLen |           0.458 |
# |      MaxVal_EpLen |               9 |
# |      MinVal_EpLen |               8 |
# |              Time |            49.1 |
# ---------------------------------------

# %% [markdown]
# ## Visualize learning curves

# %%
dfs = [pd.read_csv(f'./outputs/grid_psrs_oracle/seed={seed}/progress.txt', sep='\t') for seed in range(10)]

# %% [markdown]
# ### All runs

# %%
for df in dfs:
    plt.plot(df['AverageVal_EpLen'])
    plt.fill_between(df['Epoch'], df['MinVal_EpLen'], df['MaxVal_EpLen'], alpha=0.1)
plt.xlabel('epoch')
plt.ylabel('Val EpLen')
plt.show()

# %%
for df in dfs:
    plt.plot(df['AverageVal_EpRet'])
    plt.fill_between(df['Epoch'], df['MinVal_EpRet'], df['MaxVal_EpRet'], alpha=0.1)
plt.xlabel('epoch')
plt.ylabel('Val EpRet')
plt.show()

# %% [markdown]
# ### Averaged

# %%
df_ = pd.concat(dfs).groupby('Epoch').mean().reset_index()

# %%
plt.plot(df_['AverageVal_EpLen'], color='k')
plt.fill_between(df_['Epoch'], df_['MinVal_EpLen'], df_['MaxVal_EpLen'], alpha=0.2, color='k')
plt.xlabel('epoch')
plt.ylabel('Val EpLen')
plt.show()

# %%
plt.plot(df_['AverageVal_EpRet'], color='k')
plt.fill_between(df_['Epoch'], df_['MinVal_EpRet'], df_['MaxVal_EpRet'], alpha=0.2, color='k')
plt.xlabel('epoch')
plt.ylabel('Val EpRet')
plt.show()
